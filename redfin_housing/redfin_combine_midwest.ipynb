# %%
import pandas as pd
import numpy as np

# %%
littleRock_ar = pd.read_csv("redfin_resources/redfin_littleRockAR.csv")
milwaukee_wi = pd.read_csv("redfin_resources/redfin_milwaukeeWI.csv")
nevada_mo = pd.read_csv("redfin_resources/redfin_nevadaMO.csv")
okcity_ok = pd.read_csv("redfin_resources/redfin_okcityOK.csv")

# %%
littleRock_ar.head(2)
# Out:
#    Unnamed: 0              property_type             address         city  \
# 0           0  Single Family Residential  1 Hunters Woods Ct  Little Rock
# 1           1  Single Family Residential  254 River Ridge Pt  Little Rock
#
#   state  zip_code    price  beds  baths  square_feet  lot_size  year_built  \
# 0    AR   72210.0   295000   3.0    3.5       3877.0   20473.0      1994.0
# 1    AR   72227.0  1175000   4.0    4.0       5729.0   46173.0      2008.0
#
#    hoa_permonth                                                url   latitude  \
# 0          45.0  http://www.redfin.com/AR/Little-Rock/1-Hunters...  34.657225
# 1          61.0  http://www.redfin.com/AR/Little-Rock/254-River...  34.795144
#
#    longitude
# 0 -92.441469
# 1 -92.383638

# %%
milwaukee_wi.head(2)
# Out:
#    Unnamed: 0            property_type                      address  \
# 0           0              Condo/Co-op  929 N Astor St Unit 2501-03
# 1           1  Multi-Family (2-4 Unit)               2540 N 64th St
#
#         city state  zip_code   price  beds  baths  square_feet  lot_size  \
# 0  Milwaukee    WI     53202  619900   2.0    2.0       1791.0       NaN
# 1  Wauwatosa    WI     53213  243000   3.0    2.0       2001.0    5662.0
#
#    year_built  hoa_permonth  \
# 0      1968.0        1246.0
# 1      1941.0           NaN
#
#                                                  url   latitude  longitude
# 0  http://www.redfin.com/WI/Milwaukee/929-N-Astor...  43.043650 -87.899880
# 1  http://www.redfin.com/WI/Wauwatosa/2540-N-64th...  43.065334 -87.991832

# %%
nevada_mo.head(2)
# Out:
#    Unnamed: 0              property_type          address    city state  \
# 0           0  Single Family Residential   706 N Adams St  Nevada    MO
# 1           1  Single Family Residential  501 E Vernon St  Nevada    MO
#
#    zip_code  price  beds  baths  square_feet  lot_size  year_built  \
# 0     64772  54900   2.0    1.0       1037.0       NaN      1900.0
# 1     64772  49900   3.0    1.0       1170.0       NaN      1900.0
#
#    hoa_permonth                                                url   latitude  \
# 0           NaN  http://www.redfin.com/MO/Nevada/706-N-Adams-St...  37.844716
# 1           NaN  http://www.redfin.com/MO/Nevada/501-E-Vernon-S...  37.845570
#
#    longitude
# 0 -94.359983
# 1 -94.350672

# %%
okcity_ok.head(2)
# Out:
#    Unnamed: 0              property_type              address           city  \
# 0           0  Single Family Residential      13321 NW 7th Ct          Yukon
# 1           1  Single Family Residential  4504 Blackberry Run  Oklahoma City
#
#   state zip_code   price  beds  baths  square_feet  lot_size  year_built  \
# 0    OK    73099  319880   4.0    2.5       2191.0   12837.0      2018.0
# 1    OK    73112  415880   4.0    4.0       3512.0   15738.0      1994.0
#
#    hoa_permonth                                                url   latitude  \
# 0          20.0  http://www.redfin.com/OK/Yukon/13321-NW-7th-Ct...  35.471240
# 1          33.0  http://www.redfin.com/OK/Oklahoma-City/4504-Bl...  35.517404
#
#    longitude
# 0 -97.767844
# 1 -97.580718

# %%
frames = [milwaukee_wi, littleRock_ar, nevada_mo, okcity_ok]
redfin_midwest_combine = pd.concat(frames, ignore_index=True)

# %%
redfin_midwest_combine
# Out:
#       Unnamed: 0              property_type                      address  \
# 0              0                Condo/Co-op  929 N Astor St Unit 2501-03
# 1              1    Multi-Family (2-4 Unit)               2540 N 64th St
# 2              2  Single Family Residential           1075 Thornridge Ct
# 3              3  Single Family Residential              531 Wilmette Rd
# 4              4  Single Family Residential          5825 Cedar Creek Rd
# ...          ...                        ...                          ...
# 1112         345                Condo/Co-op   6720 N Meridian Ave Unit B
# 1113         346  Single Family Residential               200 Pawnee Cir
# 1114         347    Multi-Family (2-4 Unit)               6426 Masons Dr
# 1115         348  Single Family Residential             4705 NW 155th St
# 1116         349  Single Family Residential              3113 Shannon Ct
#
#                city state zip_code   price  beds  baths  square_feet  \
# 0         Milwaukee    WI    53202  619900   2.0    2.0       1791.0
# 1         Wauwatosa    WI    53213  243000   3.0    2.0       2001.0
# 2        Brookfield    WI    53045  365000   4.0    2.5       2406.0
# 3      Williams Bay    WI    53191  719000   3.0    2.0       1624.0
# 4           Grafton    WI    53024  745000   3.0    3.0       5000.0
# ...             ...   ...      ...     ...   ...    ...          ...
# 1112  Oklahoma City    OK    73116   69500   2.0    2.0       1196.0
# 1113          Yukon    OK    73099  180000   3.0    2.0       1733.0
# 1114  Oklahoma City    OK    73142  174900   3.0    2.5       1795.0
# 1115         Edmond    OK    73013  475500   4.0    3.5       3130.0
# 1116        Bethany    OK    73008  209900   3.0    2.0       2252.0
#
#       lot_size  year_built  hoa_permonth  \
# 0          NaN      1968.0        1246.0
# 1       5662.0      1941.0           NaN
# 2      16988.0      1978.0           NaN
# 3       5662.0      1969.0           NaN
# 4     205167.0      1869.0           NaN
# ...        ...         ...           ...
# 1112       NaN      1970.0         216.0
# 1113   10058.0      1978.0           NaN
# 1114    5279.0      1995.0         243.0
# 1115    8882.0      2012.0          33.0
# 1116    8024.0      1983.0           NaN
#
#                                                     url   latitude  longitude
# 0     http://www.redfin.com/WI/Milwaukee/929-N-Astor...  43.043650 -87.899880
# 1     http://www.redfin.com/WI/Wauwatosa/2540-N-64th...  43.065334 -87.991832
# 2     http://www.redfin.com/WI/Brookfield/1075-Thorn...  43.045303 -88.172795
# 3     http://www.redfin.com/WI/Williams-Bay/531-Wilm...  42.577095 -88.528413
# 4     http://www.redfin.com/WI/Grafton/5825-Cedar-Cr...  43.336872 -87.982725
# ...                                                 ...        ...        ...
# 1112  http://www.redfin.com/OK/Oklahoma-City/6720-D-...  35.540125 -97.600278
# 1113  http://www.redfin.com/OK/Yukon/200-Pawnee-Cir-...  35.467653 -97.736090
# 1114  http://www.redfin.com/OK/Oklahoma-City/6426-Ma...  35.602079 -97.628323
# 1115  http://www.redfin.com/OK/Edmond/4705-NW-155th-...  35.628355 -97.607294
# 1116  http://www.redfin.com/OK/Bethany/3113-Shannon-...  35.501313 -97.661635
#
# [1117 rows x 16 columns]

# %%
redfin_midwest = redfin_midwest_combine.drop(columns=['Unnamed: 0'])

# %%
redfin_midwest
# Out:
#                   property_type                      address           city  \
# 0                   Condo/Co-op  929 N Astor St Unit 2501-03      Milwaukee
# 1       Multi-Family (2-4 Unit)               2540 N 64th St      Wauwatosa
# 2     Single Family Residential           1075 Thornridge Ct     Brookfield
# 3     Single Family Residential              531 Wilmette Rd   Williams Bay
# 4     Single Family Residential          5825 Cedar Creek Rd        Grafton
# ...                         ...                          ...            ...
# 1112                Condo/Co-op   6720 N Meridian Ave Unit B  Oklahoma City
# 1113  Single Family Residential               200 Pawnee Cir          Yukon
# 1114    Multi-Family (2-4 Unit)               6426 Masons Dr  Oklahoma City
# 1115  Single Family Residential             4705 NW 155th St         Edmond
# 1116  Single Family Residential              3113 Shannon Ct        Bethany
#
#      state zip_code   price  beds  baths  square_feet  lot_size  year_built  \
# 0       WI    53202  619900   2.0    2.0       1791.0       NaN      1968.0
# 1       WI    53213  243000   3.0    2.0       2001.0    5662.0      1941.0
# 2       WI    53045  365000   4.0    2.5       2406.0   16988.0      1978.0
# 3       WI    53191  719000   3.0    2.0       1624.0    5662.0      1969.0
# 4       WI    53024  745000   3.0    3.0       5000.0  205167.0      1869.0
# ...    ...      ...     ...   ...    ...          ...       ...         ...
# 1112    OK    73116   69500   2.0    2.0       1196.0       NaN      1970.0
# 1113    OK    73099  180000   3.0    2.0       1733.0   10058.0      1978.0
# 1114    OK    73142  174900   3.0    2.5       1795.0    5279.0      1995.0
# 1115    OK    73013  475500   4.0    3.5       3130.0    8882.0      2012.0
# 1116    OK    73008  209900   3.0    2.0       2252.0    8024.0      1983.0
#
#       hoa_permonth                                                url  \
# 0           1246.0  http://www.redfin.com/WI/Milwaukee/929-N-Astor...
# 1              0.0  http://www.redfin.com/WI/Wauwatosa/2540-N-64th...
# 2              0.0  http://www.redfin.com/WI/Brookfield/1075-Thorn...
# 3              0.0  http://www.redfin.com/WI/Williams-Bay/531-Wilm...
# 4              0.0  http://www.redfin.com/WI/Grafton/5825-Cedar-Cr...
# ...            ...                                                ...
# 1112         216.0  http://www.redfin.com/OK/Oklahoma-City/6720-D-...
# 1113           0.0  http://www.redfin.com/OK/Yukon/200-Pawnee-Cir-...
# 1114         243.0  http://www.redfin.com/OK/Oklahoma-City/6426-Ma...
# 1115          33.0  http://www.redfin.com/OK/Edmond/4705-NW-155th-...
# 1116           0.0  http://www.redfin.com/OK/Bethany/3113-Shannon-...
#
#        latitude  longitude
# 0     43.043650 -87.899880
# 1     43.065334 -87.991832
# 2     43.045303 -88.172795
# 3     42.577095 -88.528413
# 4     43.336872 -87.982725
# ...         ...        ...
# 1112  35.540125 -97.600278
# 1113  35.467653 -97.736090
# 1114  35.602079 -97.628323
# 1115  35.628355 -97.607294
# 1116  35.501313 -97.661635
#
# [1117 rows x 15 columns]

# %%
redfin_midwest['hoa_permonth'] = redfin_midwest['hoa_permonth'].fillna(0)

# %%
redfin_midwest['lot_size'] = redfin_midwest['lot_size'].fillna(0)

# %%
redfin_midwest['beds'] = redfin_midwest['beds'].fillna(0)

# %%
redfin_midwest['baths'] = redfin_midwest['baths'].fillna(0)

# %%
redfin_midwest['square_feet'] = redfin_midwest['square_feet'].fillna(0)

# %%
redfin_midwest['year_built'] = redfin_midwest['year_built'].fillna('unknown')

# %%
redfin_midwest_dropna = redfin_midwest.dropna()
redfin_midwest_dropna
# Out:
#                   property_type                      address           city  \
# 0                   Condo/Co-op  929 N Astor St Unit 2501-03      Milwaukee
# 1       Multi-Family (2-4 Unit)               2540 N 64th St      Wauwatosa
# 2     Single Family Residential           1075 Thornridge Ct     Brookfield
# 3     Single Family Residential              531 Wilmette Rd   Williams Bay
# 4     Single Family Residential          5825 Cedar Creek Rd        Grafton
# ...                         ...                          ...            ...
# 1112                Condo/Co-op   6720 N Meridian Ave Unit B  Oklahoma City
# 1113  Single Family Residential               200 Pawnee Cir          Yukon
# 1114    Multi-Family (2-4 Unit)               6426 Masons Dr  Oklahoma City
# 1115  Single Family Residential             4705 NW 155th St         Edmond
# 1116  Single Family Residential              3113 Shannon Ct        Bethany
#
#      state zip_code   price  beds  baths  square_feet  lot_size year_built  \
# 0       WI    53202  619900   2.0    2.0       1791.0       0.0       1968
# 1       WI    53213  243000   3.0    2.0       2001.0    5662.0       1941
# 2       WI    53045  365000   4.0    2.5       2406.0   16988.0       1978
# 3       WI    53191  719000   3.0    2.0       1624.0    5662.0       1969
# 4       WI    53024  745000   3.0    3.0       5000.0  205167.0       1869
# ...    ...      ...     ...   ...    ...          ...       ...        ...
# 1112    OK    73116   69500   2.0    2.0       1196.0       0.0       1970
# 1113    OK    73099  180000   3.0    2.0       1733.0   10058.0       1978
# 1114    OK    73142  174900   3.0    2.5       1795.0    5279.0       1995
# 1115    OK    73013  475500   4.0    3.5       3130.0    8882.0       2012
# 1116    OK    73008  209900   3.0    2.0       2252.0    8024.0       1983
#
#       hoa_permonth                                                url  \
# 0           1246.0  http://www.redfin.com/WI/Milwaukee/929-N-Astor...
# 1              0.0  http://www.redfin.com/WI/Wauwatosa/2540-N-64th...
# 2              0.0  http://www.redfin.com/WI/Brookfield/1075-Thorn...
# 3              0.0  http://www.redfin.com/WI/Williams-Bay/531-Wilm...
# 4              0.0  http://www.redfin.com/WI/Grafton/5825-Cedar-Cr...
# ...            ...                                                ...
# 1112         216.0  http://www.redfin.com/OK/Oklahoma-City/6720-D-...
# 1113           0.0  http://www.redfin.com/OK/Yukon/200-Pawnee-Cir-...
# 1114         243.0  http://www.redfin.com/OK/Oklahoma-City/6426-Ma...
# 1115          33.0  http://www.redfin.com/OK/Edmond/4705-NW-155th-...
# 1116           0.0  http://www.redfin.com/OK/Bethany/3113-Shannon-...
#
#        latitude  longitude
# 0     43.043650 -87.899880
# 1     43.065334 -87.991832
# 2     43.045303 -88.172795
# 3     42.577095 -88.528413
# 4     43.336872 -87.982725
# ...         ...        ...
# 1112  35.540125 -97.600278
# 1113  35.467653 -97.736090
# 1114  35.602079 -97.628323
# 1115  35.628355 -97.607294
# 1116  35.501313 -97.661635
#
# [1101 rows x 15 columns]

# %%
midwest_new_index = redfin_midwest_dropna.reset_index(drop=True)

# %%
midwest_new_index
# Out:
#                   property_type                      address           city  \
# 0                   Condo/Co-op  929 N Astor St Unit 2501-03      Milwaukee
# 1       Multi-Family (2-4 Unit)               2540 N 64th St      Wauwatosa
# 2     Single Family Residential           1075 Thornridge Ct     Brookfield
# 3     Single Family Residential              531 Wilmette Rd   Williams Bay
# 4     Single Family Residential          5825 Cedar Creek Rd        Grafton
# ...                         ...                          ...            ...
# 1096                Condo/Co-op   6720 N Meridian Ave Unit B  Oklahoma City
# 1097  Single Family Residential               200 Pawnee Cir          Yukon
# 1098    Multi-Family (2-4 Unit)               6426 Masons Dr  Oklahoma City
# 1099  Single Family Residential             4705 NW 155th St         Edmond
# 1100  Single Family Residential              3113 Shannon Ct        Bethany
#
#      state zip_code   price  beds  baths  square_feet  lot_size year_built  \
# 0       WI    53202  619900   2.0    2.0       1791.0       0.0       1968
# 1       WI    53213  243000   3.0    2.0       2001.0    5662.0       1941
# 2       WI    53045  365000   4.0    2.5       2406.0   16988.0       1978
# 3       WI    53191  719000   3.0    2.0       1624.0    5662.0       1969
# 4       WI    53024  745000   3.0    3.0       5000.0  205167.0       1869
# ...    ...      ...     ...   ...    ...          ...       ...        ...
# 1096    OK    73116   69500   2.0    2.0       1196.0       0.0       1970
# 1097    OK    73099  180000   3.0    2.0       1733.0   10058.0       1978
# 1098    OK    73142  174900   3.0    2.5       1795.0    5279.0       1995
# 1099    OK    73013  475500   4.0    3.5       3130.0    8882.0       2012
# 1100    OK    73008  209900   3.0    2.0       2252.0    8024.0       1983
#
#       hoa_permonth                                                url  \
# 0           1246.0  http://www.redfin.com/WI/Milwaukee/929-N-Astor...
# 1              0.0  http://www.redfin.com/WI/Wauwatosa/2540-N-64th...
# 2              0.0  http://www.redfin.com/WI/Brookfield/1075-Thorn...
# 3              0.0  http://www.redfin.com/WI/Williams-Bay/531-Wilm...
# 4              0.0  http://www.redfin.com/WI/Grafton/5825-Cedar-Cr...
# ...            ...                                                ...
# 1096         216.0  http://www.redfin.com/OK/Oklahoma-City/6720-D-...
# 1097           0.0  http://www.redfin.com/OK/Yukon/200-Pawnee-Cir-...
# 1098         243.0  http://www.redfin.com/OK/Oklahoma-City/6426-Ma...
# 1099          33.0  http://www.redfin.com/OK/Edmond/4705-NW-155th-...
# 1100           0.0  http://www.redfin.com/OK/Bethany/3113-Shannon-...
#
#        latitude  longitude
# 0     43.043650 -87.899880
# 1     43.065334 -87.991832
# 2     43.045303 -88.172795
# 3     42.577095 -88.528413
# 4     43.336872 -87.982725
# ...         ...        ...
# 1096  35.540125 -97.600278
# 1097  35.467653 -97.736090
# 1098  35.602079 -97.628323
# 1099  35.628355 -97.607294
# 1100  35.501313 -97.661635
#
# [1101 rows x 15 columns]

# %%
midwest_new_index.to_csv('redfin_resources/combined_regions/redfin_midwest_combined.csv')
