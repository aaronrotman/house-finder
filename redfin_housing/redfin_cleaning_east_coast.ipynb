# %%
# Dependencies 
import pandas as pd
import numpy as np

# %%
# Read in Redfin data from csv files 
boston_ma = pd.read_csv("eastcoast_redfin/boston_2020-08-06-13-22-39.csv")
nashville_tn = pd.read_csv("eastcoast_redfin/nashville_2020-08-06-13-19-58.csv")
washington_dc = pd.read_csv("eastcoast_redfin/washington_dc_2020-08-06-13-23-51.csv")
miami_fl = pd.read_csv("eastcoast_redfin/miami_2020-08-06-13-17-23.csv")
newyork_ny = pd.read_csv("eastcoast_redfin/new_york_2020-08-06-13-15-57.csv")
connecticut = pd.read_csv("eastcoast_redfin/connecticut.csv")

# %%
# Preview Data

#Boston
boston_ma.head()
# Out:
#      SALE TYPE  SOLD DATE              PROPERTY TYPE                ADDRESS  \
# 0  MLS Listing        NaN  Single Family Residential           21 Grimes St
# 1  MLS Listing        NaN                Condo/Co-op        16 Mystic St #2
# 2  MLS Listing        NaN                Condo/Co-op  146 Marlborough St #1
# 3  MLS Listing        NaN                Condo/Co-op     1 Howard Pl Unit C
# 4  MLS Listing        NaN                Condo/Co-op    43 Park Vale Ave #7
#
#      CITY STATE OR PROVINCE  ZIP OR POSTAL CODE   PRICE  BEDS  BATHS  ...  \
# 0  Boston                MA                2127  649999     2    2.0  ...
# 1  Boston                MA                2129  620000     2    1.0  ...
# 2  Boston                MA                2116  498000     1    1.0  ...
# 3  Boston                MA                2125  469000     3    1.0  ...
# 4  Boston                MA                2134  499000     3    1.0  ...
#
#    STATUS  NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0  Active                         NaN                       NaN
# 1  Active                         NaN                       NaN
# 2  Active                         NaN                       NaN
# 3  Active                         NaN                       NaN
# 4  Active                         NaN                       NaN
#
#    URL (SEE http://www.redfin.com/buy-a-home/comparative-market-analysis FOR INFO ON PRICING)  \
# 0  http://www.redfin.com/MA/Boston/21-Grimes-St-0...
# 1  http://www.redfin.com/MA/Boston/16-Mystic-St-0...
# 2  http://www.redfin.com/MA/Boston/146-Marlboroug...
# 3  http://www.redfin.com/MA/Boston/1-Howard-Pl-02...
# 4  http://www.redfin.com/MA/Boston/43-Park-Vale-A...
#
#     SOURCE      MLS#  FAVORITE INTERESTED   LATITUDE  LONGITUDE
# 0  MLS PIN  72705094         N          Y  42.333760 -71.051837
# 1  MLS PIN  72704213         N          Y  42.379717 -71.062921
# 2  MLS PIN  72701696         N          Y  42.352752 -71.078148
# 3  MLS PIN  72700175         N          Y  42.319776 -71.071925
# 4  MLS PIN  72692581         N          Y  42.352307 -71.132991
#
# [5 rows x 27 columns]

# %%
# Nashville
nashville_tn.head()
# Out:
#      SALE TYPE  SOLD DATE              PROPERTY TYPE                 ADDRESS  \
# 0  MLS Listing        NaN  Single Family Residential   7516 Old Harding Pike
# 1  MLS Listing        NaN  Single Family Residential  5864 Seven Points Trce
# 2  MLS Listing        NaN                  Townhouse     101 Morton Mill Cir
# 3  MLS Listing        NaN  Single Family Residential          5954 Temple Rd
# 4  MLS Listing        NaN  Single Family Residential         3504 Lealand Ln
#
#         CITY STATE OR PROVINCE  ZIP OR POSTAL CODE     PRICE  BEDS  BATHS  \
# 0  Nashville                TN               37221  375000.0     3    2.0
# 1  Hermitage                TN               37076  389900.0     4    3.0
# 2  Nashville                TN               37221  379999.0     4    3.5
# 3  Nashville                TN               37221  399900.0     4    3.5
# 4  Nashville                TN               37204  915000.0     4    3.5
#
#    ...  STATUS  NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0  ...  Active                         NaN                       NaN
# 1  ...  Active                         NaN                       NaN
# 2  ...  Active                         NaN                       NaN
# 3  ...  Active                         NaN                       NaN
# 4  ...  Active                         NaN                       NaN
#
#    URL (SEE http://www.redfin.com/buy-a-home/comparative-market-analysis FOR INFO ON PRICING)  \
# 0  http://www.redfin.com/TN/Nashville/7516-Old-Ha...
# 1  http://www.redfin.com/TN/Hermitage/5864-Seven-...
# 2  http://www.redfin.com/TN/Nashville/101-Morton-...
# 3  http://www.redfin.com/TN/Nashville/5954-Temple...
# 4  http://www.redfin.com/TN/Nashville/3504-Lealan...
#
#       SOURCE     MLS#  FAVORITE INTERESTED   LATITUDE  LONGITUDE
# 0  REALTRACS  2175217         N          Y  36.062685 -86.942815
# 1  REALTRACS  2174804         N          Y  36.150276 -86.578165
# 2  REALTRACS  2174634         N          Y  36.065512 -86.957805
# 3  REALTRACS  2172688         N          Y  36.041489 -86.951586
# 4  REALTRACS  2167964         N          Y  36.110366 -86.787093
#
# [5 rows x 27 columns]

# %%
# Washington DC
washington_dc.head()
# Out:
#      SALE TYPE  SOLD DATE PROPERTY TYPE                   ADDRESS  \
# 0  MLS Listing        NaN   Condo/Co-op   834 Lamont St NW Unit A
# 1  MLS Listing        NaN     Townhouse            4919 7th St NW
# 2  MLS Listing        NaN     Townhouse              1111 R St NW
# 3  MLS Listing        NaN   Condo/Co-op      1423 R St NW Unit G1
# 4  MLS Listing        NaN   Condo/Co-op  437 New York Ave NW #222
#
#             CITY STATE OR PROVINCE  ZIP OR POSTAL CODE   PRICE  BEDS  BATHS  \
# 0  Washington DC                DC               20010  549900     1    1.5
# 1  Washington DC                DC               20011  809000     4    3.5
# 2  Washington DC                DC               20009  899900     2    2.0
# 3  Washington DC                DC               20009  369000     1    1.0
# 4  Washington DC                DC               20001  525000     1    1.0
#
#    ...  STATUS  NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0  ...  Active                         NaN                       NaN
# 1  ...  Active                         NaN                       NaN
# 2  ...  Active                         NaN                       NaN
# 3  ...  Active                         NaN                       NaN
# 4  ...  Active                         NaN                       NaN
#
#    URL (SEE http://www.redfin.com/buy-a-home/comparative-market-analysis FOR INFO ON PRICING)  \
# 0  http://www.redfin.com/DC/Washington/834-Lamont...
# 1  http://www.redfin.com/DC/Washington/4919-7th-S...
# 2  http://www.redfin.com/DC/Washington/1111-R-St-...
# 3  http://www.redfin.com/DC/Washington/1423-R-St-...
# 4  http://www.redfin.com/DC/Washington/437-New-Yo...
#
#        SOURCE        MLS#  FAVORITE INTERESTED   LATITUDE  LONGITUDE
# 0  BRIGHT MLS  DCDC480622         N          Y  38.930660 -77.026082
# 1  BRIGHT MLS  DCDC479542         N          Y  38.950479 -77.021823
# 2  BRIGHT MLS  DCDC480796         N          Y  38.912779 -77.027491
# 3  BRIGHT MLS  DCDC480636         N          Y  38.912889 -77.033124
# 4  BRIGHT MLS  DCDC479538         N          Y  38.904948 -77.017092
#
# [5 rows x 27 columns]

# %%
# Miami
miami_fl.head()
# Out:
#      SALE TYPE  SOLD DATE              PROPERTY TYPE  \
# 0  MLS Listing        NaN   Mobile/Manufactured Home
# 1  MLS Listing        NaN  Single Family Residential
# 2  MLS Listing        NaN                Condo/Co-op
# 3  MLS Listing        NaN                Condo/Co-op
# 4  MLS Listing        NaN                Condo/Co-op
#
#                       ADDRESS       CITY STATE OR PROVINCE  \
# 0           35250 SW 177th Ct  Homestead                FL
# 1        1200 Brickell Bay Dr      Miami                FL
# 2  1200 Brickell Bay Dr #2417      Miami                FL
# 3  1200 Brickell Bay Dr #3919      Miami                FL
# 4  1200 Brickell Bay Dr #1704      Miami                FL
#
#    ZIP OR POSTAL CODE   PRICE  BEDS  BATHS  ...  STATUS  \
# 0             33034.0  130000     3    2.0  ...  Active
# 1             33131.0  438500     3    2.0  ...  Active
# 2             33131.0  285000     1    1.0  ...  Active
# 3             33131.0  280000     1    1.0  ...  Active
# 4             33131.0  289000     1    1.0  ...  Active
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
#
#    URL (SEE http://www.redfin.com/buy-a-home/comparative-market-analysis FOR INFO ON PRICING)  \
# 0  http://www.redfin.com/FL/Miami/35250-SW-177-CT...
# 1  http://www.redfin.com/FL/Miami/1200-Brickell-B...
# 2  http://www.redfin.com/FL/Miami/1200-Brickell-B...
# 3  http://www.redfin.com/FL/Miami/1200-Brickell-B...
# 4  http://www.redfin.com/FL/Miami/1200-Brickell-B...
#
#    SOURCE       MLS#  FAVORITE INTERESTED   LATITUDE  LONGITUDE
# 0  MARMLS  A10867173         N          Y  25.761680 -80.191790
# 1  MARMLS  A10878153         N          Y  25.761804 -80.190589
# 2  MARMLS  A10866546         N          Y  25.761804 -80.190589
# 3  MARMLS  A10879321         N          Y  25.761804 -80.190589
# 4  MARMLS  A10903812         N          Y  25.761804 -80.190589
#
# [5 rows x 27 columns]

# %%
# New York
newyork_ny.head()
# Out:
#      SALE TYPE  SOLD DATE              PROPERTY TYPE                  ADDRESS  \
# 0  MLS Listing        NaN                Condo/Co-op    1 Bay Club Dr Unit 1R
# 1  MLS Listing        NaN  Single Family Residential             28-31 215 St
# 2  MLS Listing        NaN  Single Family Residential             53-25 210 St
# 3  MLS Listing        NaN                Condo/Co-op  23-20 Bell Blvd Unit 2H
# 4  MLS Listing        NaN  Single Family Residential           81-03 252nd St
#
#         CITY STATE OR PROVINCE  ZIP OR POSTAL CODE    PRICE  BEDS  BATHS  ...  \
# 0    Bayside                NY               11360   638000   2.0    1.0  ...
# 1    Bayside                NY               11360  1299000   4.0    3.0  ...
# 2    Bayside                NY               11364   749000   3.0    1.0  ...
# 3    Bayside                NY               11360   448000   2.0    2.0  ...
# 4  Bellerose                NY               11426  1149000   5.0    3.0  ...
#
#    STATUS  NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0  Active                         NaN                       NaN
# 1  Active      August-9-2020 02:00 PM    August-9-2020 04:00 PM
# 2  Active      August-8-2020 12:00 PM    August-8-2020 02:00 PM
# 3  Active     August-11-2020 06:00 PM   August-11-2020 07:30 PM
# 4  Active                         NaN                       NaN
#
#    URL (SEE http://www.redfin.com/buy-a-home/comparative-market-analysis FOR INFO ON PRICING)  \
# 0  http://www.redfin.com/NY/Bayside/1-Bay-Club-Dr...
# 1  http://www.redfin.com/NY/Flushing/28-31-215th-...
# 2  http://www.redfin.com/NY/Flushing/53-25-210th-...
# 3  http://www.redfin.com/NY/Bayside/23-20-Bell-Bl...
# 4  http://www.redfin.com/NY/Jamaica/81-03-252nd-S...
#
#    SOURCE     MLS#  FAVORITE INTERESTED   LATITUDE  LONGITUDE
# 0  OneKey  3240176         N          Y  40.778441 -73.780429
# 1  OneKey  3240168         N          Y  40.776973 -73.772345
# 2  OneKey  3240051         N          Y  40.750646 -73.768576
# 3  OneKey  3240044         N          Y  40.781705 -73.776514
# 4  OneKey  3240266         N          Y  40.741290 -73.717369
#
# [5 rows x 27 columns]

# %%
boston_ma_dropped_col = boston_ma.drop(columns=['SALE TYPE', 'SOLD DATE', 'DAYS ON MARKET', '$/SQUARE FEET', 'STATUS', 'NEXT OPEN HOUSE START TIME', 
                            'NEXT OPEN HOUSE END TIME', 'SOURCE', 'MLS#', 'FAVORITE', 'INTERESTED', "LOCATION"])

nashville_tn_dropped_col = nashville_tn.drop(columns=['SALE TYPE', 'SOLD DATE', 'DAYS ON MARKET', '$/SQUARE FEET', 'STATUS', 'NEXT OPEN HOUSE START TIME', 
                            'NEXT OPEN HOUSE END TIME', 'SOURCE', 'MLS#', 'FAVORITE', 'INTERESTED', "LOCATION"])

washington_dc_dropped_col = washington_dc.drop(columns=['SALE TYPE', 'SOLD DATE', 'DAYS ON MARKET', '$/SQUARE FEET', 'STATUS', 'NEXT OPEN HOUSE START TIME', 
                            'NEXT OPEN HOUSE END TIME', 'SOURCE', 'MLS#', 'FAVORITE', 'INTERESTED', "LOCATION"])

miami_fl_dropped_col = miami_fl.drop(columns=['SALE TYPE', 'SOLD DATE', 'DAYS ON MARKET', '$/SQUARE FEET', 'STATUS', 'NEXT OPEN HOUSE START TIME', 
                            'NEXT OPEN HOUSE END TIME', 'SOURCE', 'MLS#', 'FAVORITE', 'INTERESTED', "LOCATION"])

newyork_ny_dropped_col = newyork_ny.drop(columns=['SALE TYPE', 'SOLD DATE', 'DAYS ON MARKET', '$/SQUARE FEET', 'STATUS', 'NEXT OPEN HOUSE START TIME', 
                            'NEXT OPEN HOUSE END TIME', 'SOURCE', 'MLS#', 'FAVORITE', 'INTERESTED', "LOCATION"])
connecticut_dropped = connecticut

# %%
boston_ma_renamed = boston_ma_dropped_col.rename(columns={"PROPERTY TYPE": "property_type", "ADDRESS": "address", "CITY":"city", "STATE OR PROVINCE":"state",
                             "ZIP OR POSTAL CODE":"zip_code", "PRICE":"price", "BEDS":"beds", "BATHS":"baths",
                             "SQUARE FEET":"square_feet", "LOT SIZE":'lot_size', 
                              "YEAR BUILT":"year_built", "HOA/MONTH":"hoa_permonth", 
                              "URL (SEE http://www.redfin.com/buy-a-home/comparative-market-analysis FOR INFO ON PRICING)":"url",
                              "LATITUDE":"latitude", "LONGITUDE":"longitude"})

nashville_tn_renamed = nashville_tn_dropped_col.rename(columns={"PROPERTY TYPE": "property_type", "ADDRESS": "address", "CITY":"city", "STATE OR PROVINCE":"state",
                             "ZIP OR POSTAL CODE":"zip_code", "PRICE":"price", "BEDS":"beds", "BATHS":"baths",
                             "SQUARE FEET":"square_feet", "LOT SIZE":'lot_size', 
                              "YEAR BUILT":"year_built", "HOA/MONTH":"hoa_permonth", 
                              "URL (SEE http://www.redfin.com/buy-a-home/comparative-market-analysis FOR INFO ON PRICING)":"url",
                              "LATITUDE":"latitude", "LONGITUDE":"longitude"})

washington_dc_renamed = washington_dc_dropped_col.rename(columns={"PROPERTY TYPE": "property_type", "ADDRESS": "address", "CITY":"city", "STATE OR PROVINCE":"state",
                             "ZIP OR POSTAL CODE":"zip_code", "PRICE":"price", "BEDS":"beds", "BATHS":"baths",
                             "SQUARE FEET":"square_feet", "LOT SIZE":'lot_size', 
                              "YEAR BUILT":"year_built", "HOA/MONTH":"hoa_permonth", 
                              "URL (SEE http://www.redfin.com/buy-a-home/comparative-market-analysis FOR INFO ON PRICING)":"url",
                              "LATITUDE":"latitude", "LONGITUDE":"longitude"})

miami_fl_renamed = miami_fl_dropped_col.rename(columns={"PROPERTY TYPE": "property_type", "ADDRESS": "address", "CITY":"city", "STATE OR PROVINCE":"state",
                             "ZIP OR POSTAL CODE":"zip_code", "PRICE":"price", "BEDS":"beds", "BATHS":"baths",
                             "SQUARE FEET":"square_feet", "LOT SIZE":'lot_size', 
                              "YEAR BUILT":"year_built", "HOA/MONTH":"hoa_permonth", 
                              "URL (SEE http://www.redfin.com/buy-a-home/comparative-market-analysis FOR INFO ON PRICING)":"url",
                              "LATITUDE":"latitude", "LONGITUDE":"longitude"})

newyork_ny_renamed = newyork_ny_dropped_col.rename(columns={"PROPERTY TYPE": "property_type", "ADDRESS": "address", "CITY":"city", "STATE OR PROVINCE":"state",
                             "ZIP OR POSTAL CODE":"zip_code", "PRICE":"price", "BEDS":"beds", "BATHS":"baths",
                             "SQUARE FEET":"square_feet", "LOT SIZE":'lot_size', 
                              "YEAR BUILT":"year_built", "HOA/MONTH":"hoa_permonth", 
                              "URL (SEE http://www.redfin.com/buy-a-home/comparative-market-analysis FOR INFO ON PRICING)":"url",
                              "LATITUDE":"latitude", "LONGITUDE":"longitude"})

connecticut_renamed = connecticut_dropped.rename(columns={"PROPERTY TYPE": "property_type", "ADDRESS": "address", "CITY":"city", "STATE OR PROVINCE":"state",
                             "ZIP OR POSTAL CODE":"zip_code", "PRICE":"price", "BEDS":"beds", "BATHS":"baths",
                             "SQUARE FEET":"square_feet", "LOT SIZE":'lot_size', 
                              "YEAR BUILT":"year_built", "HOA/MONTH":"hoa_permonth", 
                              "URL (SEE http://www.redfin.com/buy-a-home/comparative-market-analysis FOR INFO ON PRICING)":"url",
                              "LATITUDE":"latitude", "LONGITUDE":"longitude"})

# %%
boston_ma_renamed.to_csv("redfin_resources/redfin_boston_ma.csv")
nashville_tn_renamed.to_csv("redfin_resources/redfin_nashville_tn.csv")
washington_dc_renamed.to_csv("redfin_resources/redfin_washington_dc.csv")
miami_fl_renamed.to_csv("redfin_resources/redfin_miami_fl.csv")
newyork_ny_renamed.to_csv("redfin_resources/redfin_newyork_ny.csv")
connecticut_renamed.to_csv("redfin_resources/connecticut.csv")
