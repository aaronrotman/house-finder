# %%
import pandas as pd
import numpy as np

# %%
littleRock_ar = pd.read_csv("original_files/littlerock_ar_housing_original.csv")
milwaukee_wi = pd.read_csv("original_files/milwaukee_wi_housing_original.csv")
nevada_mo = pd.read_csv("original_files/nevada_mo_housing_original.csv")
okcity_ok = pd.read_csv("original_files/okcity_ok_housing_original.csv")

# %%
littleRock_ar.head(2)
# Out:
#      SALE TYPE  SOLD DATE              PROPERTY TYPE             ADDRESS  \
# 0  MLS Listing        NaN  Single Family Residential  1 Hunters Woods Ct
# 1  MLS Listing        NaN  Single Family Residential  254 River Ridge Pt
#
#           CITY STATE OR PROVINCE  ZIP OR POSTAL CODE    PRICE  BEDS  BATHS  \
# 0  Little Rock                AR             72210.0   295000   3.0    3.5
# 1  Little Rock                AR             72227.0  1175000   4.0    4.0
#
#    ...  STATUS  NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0  ...  Active                         NaN                       NaN
# 1  ...  Active                         NaN                       NaN
#
#    URL (SEE http://www.redfin.com/buy-a-home/comparative-market-analysis FOR INFO ON PRICING)  \
# 0  http://www.redfin.com/AR/Little-Rock/1-Hunters...
# 1  http://www.redfin.com/AR/Little-Rock/254-River...
#
#    SOURCE      MLS#  FAVORITE INTERESTED   LATITUDE  LONGITUDE
# 0  CARMLS  20023641         N          Y  34.657225 -92.441469
# 1  CARMLS  20020974         N          Y  34.795144 -92.383638
#
# [2 rows x 27 columns]

# %%
milwaukee_wi.head(2)
# Out:
#      SALE TYPE  SOLD DATE            PROPERTY TYPE  \
# 0  MLS Listing        NaN              Condo/Co-op
# 1  MLS Listing        NaN  Multi-Family (2-4 Unit)
#
#                        ADDRESS       CITY STATE OR PROVINCE  \
# 0  929 N Astor St Unit 2501-03  Milwaukee                WI
# 1               2540 N 64th St  Wauwatosa                WI
#
#    ZIP OR POSTAL CODE   PRICE  BEDS  BATHS  ...  STATUS  \
# 0               53202  619900   2.0    2.0  ...  Active
# 1               53213  243000   3.0    2.0  ...  Active
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
#
#    URL (SEE http://www.redfin.com/buy-a-home/comparative-market-analysis FOR INFO ON PRICING)  \
# 0  http://www.redfin.com/WI/Milwaukee/929-N-Astor...
# 1  http://www.redfin.com/WI/Wauwatosa/2540-N-64th...
#
#      SOURCE     MLS#  FAVORITE INTERESTED   LATITUDE  LONGITUDE
# 0  METROMLS  1702414         N          Y  43.043650 -87.899880
# 1  METROMLS  1699569         N          Y  43.065334 -87.991832
#
# [2 rows x 27 columns]

# %%
nevada_mo.head(2)
# Out:
#      SALE TYPE  SOLD DATE              PROPERTY TYPE          ADDRESS    CITY  \
# 0  MLS Listing        NaN  Single Family Residential   706 N Adams St  Nevada
# 1  MLS Listing        NaN  Single Family Residential  501 E Vernon St  Nevada
#
#   STATE OR PROVINCE  ZIP OR POSTAL CODE  PRICE  BEDS  BATHS  ...  STATUS  \
# 0                MO               64772  54900   2.0    1.0  ...  Active
# 1                MO               64772  49900   3.0    1.0  ...  Active
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
#
#    URL (SEE http://www.redfin.com/buy-a-home/comparative-market-analysis FOR INFO ON PRICING)  \
# 0  http://www.redfin.com/MO/Nevada/706-N-Adams-St...
# 1  http://www.redfin.com/MO/Nevada/501-E-Vernon-S...
#
#           SOURCE     MLS#  FAVORITE INTERESTED   LATITUDE  LONGITUDE
# 0  Heartland MLS  2234611         N          Y  37.844716 -94.359983
# 1  Heartland MLS  2234610         N          Y  37.845570 -94.350672
#
# [2 rows x 27 columns]

# %%
okcity_ok.head(2)
# Out:
#      SALE TYPE  SOLD DATE              PROPERTY TYPE              ADDRESS  \
# 0  MLS Listing        NaN  Single Family Residential      13321 NW 7th Ct
# 1  MLS Listing        NaN  Single Family Residential  4504 Blackberry Run
#
#             CITY STATE OR PROVINCE ZIP OR POSTAL CODE   PRICE  BEDS  BATHS  \
# 0          Yukon                OK              73099  319880   4.0    2.5
# 1  Oklahoma City                OK              73112  415880   4.0    4.0
#
#    ...  STATUS  NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0  ...  Active                         NaN                       NaN
# 1  ...  Active                         NaN                       NaN
#
#    URL (SEE http://www.redfin.com/buy-a-home/comparative-market-analysis FOR INFO ON PRICING)  \
# 0  http://www.redfin.com/OK/Yukon/13321-NW-7th-Ct...
# 1  http://www.redfin.com/OK/Oklahoma-City/4504-Bl...
#
#    SOURCE    MLS#  FAVORITE INTERESTED   LATITUDE  LONGITUDE
# 0   MLSOK  921981         N          Y  35.471240 -97.767844
# 1   MLSOK  901629         N          Y  35.517404 -97.580718
#
# [2 rows x 27 columns]

# %%
# for col in littleRock_ar.columns: 
#     print(col)

# %%
little_rock_ar_dropped_col = littleRock_ar.drop(columns=['SALE TYPE', 'SOLD DATE', 'DAYS ON MARKET', '$/SQUARE FEET', 'STATUS', 'NEXT OPEN HOUSE START TIME', 
                            'NEXT OPEN HOUSE END TIME', 'SOURCE', 'MLS#', 'FAVORITE', 'INTERESTED', "LOCATION"])

milwaukee_wi_dropped_col = milwaukee_wi.drop(columns=['SALE TYPE', 'SOLD DATE', 'DAYS ON MARKET', '$/SQUARE FEET', 'STATUS', 'NEXT OPEN HOUSE START TIME', 
                            'NEXT OPEN HOUSE END TIME', 'SOURCE', 'MLS#', 'FAVORITE', 'INTERESTED', "LOCATION"])

nevada_mo_dropped_col = nevada_mo.drop(columns=['SALE TYPE', 'SOLD DATE', 'DAYS ON MARKET', '$/SQUARE FEET', 'STATUS', 'NEXT OPEN HOUSE START TIME', 
                            'NEXT OPEN HOUSE END TIME', 'SOURCE', 'MLS#', 'FAVORITE', 'INTERESTED', "LOCATION"])

okcity_ok_dropped_col = okcity_ok.drop(columns=['SALE TYPE', 'SOLD DATE', 'DAYS ON MARKET', '$/SQUARE FEET', 'STATUS', 'NEXT OPEN HOUSE START TIME', 
                            'NEXT OPEN HOUSE END TIME', 'SOURCE', 'MLS#', 'FAVORITE', 'INTERESTED', "LOCATION"])

# %%
little_rock_ar_dropped_col.head(2)
# Out:
#                PROPERTY TYPE             ADDRESS         CITY  \
# 0  Single Family Residential  1 Hunters Woods Ct  Little Rock
# 1  Single Family Residential  254 River Ridge Pt  Little Rock
#
#   STATE OR PROVINCE  ZIP OR POSTAL CODE    PRICE  BEDS  BATHS  SQUARE FEET  \
# 0                AR             72210.0   295000   3.0    3.5       3877.0
# 1                AR             72227.0  1175000   4.0    4.0       5729.0
#
#    LOT SIZE  YEAR BUILT  HOA/MONTH  \
# 0   20473.0      1994.0       45.0
# 1   46173.0      2008.0       61.0
#
#   URL (SEE http://www.redfin.com/buy-a-home/comparative-market-analysis FOR INFO ON PRICING)  \
# 0  http://www.redfin.com/AR/Little-Rock/1-Hunters...
# 1  http://www.redfin.com/AR/Little-Rock/254-River...
#
#     LATITUDE  LONGITUDE
# 0  34.657225 -92.441469
# 1  34.795144 -92.383638

# %%
milwaukee_wi_dropped_col.head(2)
# Out:
#              PROPERTY TYPE                      ADDRESS       CITY  \
# 0              Condo/Co-op  929 N Astor St Unit 2501-03  Milwaukee
# 1  Multi-Family (2-4 Unit)               2540 N 64th St  Wauwatosa
#
#   STATE OR PROVINCE  ZIP OR POSTAL CODE   PRICE  BEDS  BATHS  SQUARE FEET  \
# 0                WI               53202  619900   2.0    2.0       1791.0
# 1                WI               53213  243000   3.0    2.0       2001.0
#
#    LOT SIZE  YEAR BUILT  HOA/MONTH  \
# 0       NaN      1968.0     1246.0
# 1    5662.0      1941.0        NaN
#
#   URL (SEE http://www.redfin.com/buy-a-home/comparative-market-analysis FOR INFO ON PRICING)  \
# 0  http://www.redfin.com/WI/Milwaukee/929-N-Astor...
# 1  http://www.redfin.com/WI/Wauwatosa/2540-N-64th...
#
#     LATITUDE  LONGITUDE
# 0  43.043650 -87.899880
# 1  43.065334 -87.991832

# %%
nevada_mo_dropped_col.head(2)
# Out:
#                PROPERTY TYPE          ADDRESS    CITY STATE OR PROVINCE  \
# 0  Single Family Residential   706 N Adams St  Nevada                MO
# 1  Single Family Residential  501 E Vernon St  Nevada                MO
#
#    ZIP OR POSTAL CODE  PRICE  BEDS  BATHS  SQUARE FEET  LOT SIZE  YEAR BUILT  \
# 0               64772  54900   2.0    1.0       1037.0       NaN      1900.0
# 1               64772  49900   3.0    1.0       1170.0       NaN      1900.0
#
#    HOA/MONTH  \
# 0        NaN
# 1        NaN
#
#   URL (SEE http://www.redfin.com/buy-a-home/comparative-market-analysis FOR INFO ON PRICING)  \
# 0  http://www.redfin.com/MO/Nevada/706-N-Adams-St...
# 1  http://www.redfin.com/MO/Nevada/501-E-Vernon-S...
#
#     LATITUDE  LONGITUDE
# 0  37.844716 -94.359983
# 1  37.845570 -94.350672

# %%
okcity_ok_dropped_col.head(2)
# Out:
#                PROPERTY TYPE              ADDRESS           CITY  \
# 0  Single Family Residential      13321 NW 7th Ct          Yukon
# 1  Single Family Residential  4504 Blackberry Run  Oklahoma City
#
#   STATE OR PROVINCE ZIP OR POSTAL CODE   PRICE  BEDS  BATHS  SQUARE FEET  \
# 0                OK              73099  319880   4.0    2.5       2191.0
# 1                OK              73112  415880   4.0    4.0       3512.0
#
#    LOT SIZE  YEAR BUILT  HOA/MONTH  \
# 0   12837.0      2018.0       20.0
# 1   15738.0      1994.0       33.0
#
#   URL (SEE http://www.redfin.com/buy-a-home/comparative-market-analysis FOR INFO ON PRICING)  \
# 0  http://www.redfin.com/OK/Yukon/13321-NW-7th-Ct...
# 1  http://www.redfin.com/OK/Oklahoma-City/4504-Bl...
#
#     LATITUDE  LONGITUDE
# 0  35.471240 -97.767844
# 1  35.517404 -97.580718

# %%
little_rock_ar_renamed = little_rock_ar_dropped_col.rename(columns={"PROPERTY TYPE": "property_type", "ADDRESS": "address", "CITY":"city", "STATE OR PROVINCE":"state",
                             "ZIP OR POSTAL CODE":"zip_code", "PRICE":"price", "BEDS":"beds", "BATHS":"baths",
                             "SQUARE FEET":"square_feet", "LOT SIZE":'lot_size', 
                              "YEAR BUILT":"year_built", "HOA/MONTH":"hoa_permonth", 
                              "URL (SEE http://www.redfin.com/buy-a-home/comparative-market-analysis FOR INFO ON PRICING)":"url",
                              "LATITUDE":"latitude", "LONGITUDE":"longitude"})

milwaukee_wi_renamed = milwaukee_wi_dropped_col.rename(columns={"PROPERTY TYPE": "property_type", "ADDRESS": "address", "CITY":"city", "STATE OR PROVINCE":"state",
                             "ZIP OR POSTAL CODE":"zip_code", "PRICE":"price", "BEDS":"beds", "BATHS":"baths",
                             "SQUARE FEET":"square_feet", "LOT SIZE":'lot_size', 
                              "YEAR BUILT":"year_built", "HOA/MONTH":"hoa_permonth", 
                              "URL (SEE http://www.redfin.com/buy-a-home/comparative-market-analysis FOR INFO ON PRICING)":"url",
                              "LATITUDE":"latitude", "LONGITUDE":"longitude"})

nevada_mo_renamed = nevada_mo_dropped_col.rename(columns={"PROPERTY TYPE": "property_type", "ADDRESS": "address", "CITY":"city", "STATE OR PROVINCE":"state",
                             "ZIP OR POSTAL CODE":"zip_code", "PRICE":"price", "BEDS":"beds", "BATHS":"baths",
                             "SQUARE FEET":"square_feet", "LOT SIZE":'lot_size', 
                              "YEAR BUILT":"year_built", "HOA/MONTH":"hoa_permonth", 
                              "URL (SEE http://www.redfin.com/buy-a-home/comparative-market-analysis FOR INFO ON PRICING)":"url",
                              "LATITUDE":"latitude", "LONGITUDE":"longitude"})

okcity_ok_renamed = okcity_ok_dropped_col.rename(columns={"PROPERTY TYPE": "property_type", "ADDRESS": "address", "CITY":"city", "STATE OR PROVINCE":"state",
                             "ZIP OR POSTAL CODE":"zip_code", "PRICE":"price", "BEDS":"beds", "BATHS":"baths",
                             "SQUARE FEET":"square_feet", "LOT SIZE":'lot_size', 
                              "YEAR BUILT":"year_built", "HOA/MONTH":"hoa_permonth", 
                              "URL (SEE http://www.redfin.com/buy-a-home/comparative-market-analysis FOR INFO ON PRICING)":"url",
                              "LATITUDE":"latitude", "LONGITUDE":"longitude"})

# %%
little_rock_ar_renamed.head(2)
# Out:
#                property_type             address         city state  zip_code  \
# 0  Single Family Residential  1 Hunters Woods Ct  Little Rock    AR   72210.0
# 1  Single Family Residential  254 River Ridge Pt  Little Rock    AR   72227.0
#
#      price  beds  baths  square_feet  lot_size  year_built  hoa_permonth  \
# 0   295000   3.0    3.5       3877.0   20473.0      1994.0          45.0
# 1  1175000   4.0    4.0       5729.0   46173.0      2008.0          61.0
#
#                                                  url   latitude  longitude
# 0  http://www.redfin.com/AR/Little-Rock/1-Hunters...  34.657225 -92.441469
# 1  http://www.redfin.com/AR/Little-Rock/254-River...  34.795144 -92.383638

# %%
milwaukee_wi_renamed.head(2)
# Out:
#              property_type                      address       city state  \
# 0              Condo/Co-op  929 N Astor St Unit 2501-03  Milwaukee    WI
# 1  Multi-Family (2-4 Unit)               2540 N 64th St  Wauwatosa    WI
#
#    zip_code   price  beds  baths  square_feet  lot_size  year_built  \
# 0     53202  619900   2.0    2.0       1791.0       NaN      1968.0
# 1     53213  243000   3.0    2.0       2001.0    5662.0      1941.0
#
#    hoa_permonth                                                url   latitude  \
# 0        1246.0  http://www.redfin.com/WI/Milwaukee/929-N-Astor...  43.043650
# 1           NaN  http://www.redfin.com/WI/Wauwatosa/2540-N-64th...  43.065334
#
#    longitude
# 0 -87.899880
# 1 -87.991832

# %%
nevada_mo_renamed.head(2)
# Out:
#                property_type          address    city state  zip_code  price  \
# 0  Single Family Residential   706 N Adams St  Nevada    MO     64772  54900
# 1  Single Family Residential  501 E Vernon St  Nevada    MO     64772  49900
#
#    beds  baths  square_feet  lot_size  year_built  hoa_permonth  \
# 0   2.0    1.0       1037.0       NaN      1900.0           NaN
# 1   3.0    1.0       1170.0       NaN      1900.0           NaN
#
#                                                  url   latitude  longitude
# 0  http://www.redfin.com/MO/Nevada/706-N-Adams-St...  37.844716 -94.359983
# 1  http://www.redfin.com/MO/Nevada/501-E-Vernon-S...  37.845570 -94.350672

# %%
okcity_ok_renamed.head(2)
# Out:
#                property_type              address           city state  \
# 0  Single Family Residential      13321 NW 7th Ct          Yukon    OK
# 1  Single Family Residential  4504 Blackberry Run  Oklahoma City    OK
#
#   zip_code   price  beds  baths  square_feet  lot_size  year_built  \
# 0    73099  319880   4.0    2.5       2191.0   12837.0      2018.0
# 1    73112  415880   4.0    4.0       3512.0   15738.0      1994.0
#
#    hoa_permonth                                                url   latitude  \
# 0          20.0  http://www.redfin.com/OK/Yukon/13321-NW-7th-Ct...  35.471240
# 1          33.0  http://www.redfin.com/OK/Oklahoma-City/4504-Bl...  35.517404
#
#    longitude
# 0 -97.767844
# 1 -97.580718

# %%
little_rock_ar_renamed.to_csv("redfin_resources/redfin_littleRockAR.csv")
milwaukee_wi_renamed.to_csv("redfin_resources/redfin_milwaukeeWI.csv")
nevada_mo_renamed.to_csv("redfin_resources/redfin_nevadaMO.csv")
okcity_ok_renamed.to_csv("redfin_resources/redfin_okcityOK.csv")
