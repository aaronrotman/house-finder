# %%
import pandas as pd
import numpy as np

# %%
boston_ma = pd.read_csv("redfin_resources/redfin_boston_ma.csv")
miami_fl = pd.read_csv("redfin_resources/redfin_miami_fl.csv")
nashville_tn = pd.read_csv("redfin_resources/redfin_nashville_tn.csv")
newyork_ny = pd.read_csv("redfin_resources/redfin_newyork_ny.csv")
washington_dc = pd.read_csv("redfin_resources/redfin_washington_dc.csv")
connecticut = pd.read_csv("redfin_resources/connecticut.csv")

# %%
boston_ma.head()
# Out:
#    Unnamed: 0              property_type                address    city state  \
# 0           0  Single Family Residential           21 Grimes St  Boston    MA
# 1           1                Condo/Co-op        16 Mystic St #2  Boston    MA
# 2           2                Condo/Co-op  146 Marlborough St #1  Boston    MA
# 3           3                Condo/Co-op     1 Howard Pl Unit C  Boston    MA
# 4           4                Condo/Co-op    43 Park Vale Ave #7  Boston    MA
#
#    zip_code   price  beds  baths  square_feet  lot_size  year_built  \
# 0      2127  649999     2    2.0         1176     825.0        1890
# 1      2129  620000     2    1.0          758       NaN        1870
# 2      2116  498000     1    1.0          486     486.0        1880
# 3      2125  469000     3    1.0         1189       NaN        1905
# 4      2134  499000     3    1.0          780     780.0        1910
#
#    hoa_permonth                                                url   latitude  \
# ...

# %%
washington_dc.head()
# Out:
#    Unnamed: 0 property_type                   address           city state  \
# 0           0   Condo/Co-op   834 Lamont St NW Unit A  Washington DC    DC
# 1           1     Townhouse            4919 7th St NW  Washington DC    DC
# 2           2     Townhouse              1111 R St NW  Washington DC    DC
# 3           3   Condo/Co-op      1423 R St NW Unit G1  Washington DC    DC
# 4           4   Condo/Co-op  437 New York Ave NW #222  Washington DC    DC
#
#    zip_code   price  beds  baths  square_feet  lot_size  year_built  \
# 0     20010  549900     1    1.5        760.0       NaN        2005
# 1     20011  809000     4    3.5       2000.0    1530.0        1927
# 2     20009  899900     2    2.0       1398.0     497.0        1900
# 3     20009  369000     1    1.0        581.0       NaN        1925
# 4     20001  525000     1    1.0        870.0       NaN        2008
#
#    hoa_permonth                                                url   latitude  \
# ...

# %%
frames = [boston_ma, miami_fl, nashville_tn, newyork_ny, washington_dc, connecticut]
redfin_east_coast_combine = pd.concat(frames, ignore_index=True)

# %%
redfin_east_coast_combine
# Out:
#       Unnamed: 0              property_type                address       city  \
# 0              0  Single Family Residential           21 Grimes St     Boston
# 1              1                Condo/Co-op        16 Mystic St #2     Boston
# 2              2                Condo/Co-op  146 Marlborough St #1     Boston
# 3              3                Condo/Co-op     1 Howard Pl Unit C     Boston
# 4              4                Condo/Co-op    43 Park Vale Ave #7     Boston
# ...          ...                        ...                    ...        ...
# 4404        2775  Single Family Residential          55 Perkins Rd  Greenwich
# 4405        2776  Single Family Residential      586 Round Hill Rd  Greenwich
# 4406        2777  Single Family Residential    1233 Rock Rimmon Rd   Stamford
# 4407        2778  Single Family Residential     1111 Sasco Hill Rd  Fairfield
# 4408        2779  Single Family Residential         18 Wallacks Dr   Stamford
#
# ...

# %%
redfin_east_coast = redfin_east_coast_combine.drop(columns=['Unnamed: 0'])

# %%
redfin_east_coast
# Out:
#                   property_type                address       city state  \
# 0     Single Family Residential           21 Grimes St     Boston    MA
# 1                   Condo/Co-op        16 Mystic St #2     Boston    MA
# 2                   Condo/Co-op  146 Marlborough St #1     Boston    MA
# 3                   Condo/Co-op     1 Howard Pl Unit C     Boston    MA
# 4                   Condo/Co-op    43 Park Vale Ave #7     Boston    MA
# ...                         ...                    ...        ...   ...
# 4404  Single Family Residential          55 Perkins Rd  Greenwich    CT
# 4405  Single Family Residential      586 Round Hill Rd  Greenwich    CT
# 4406  Single Family Residential    1233 Rock Rimmon Rd   Stamford    CT
# 4407  Single Family Residential     1111 Sasco Hill Rd  Fairfield    CT
# 4408  Single Family Residential         18 Wallacks Dr   Stamford    CT
#
#       zip_code       price  beds  baths  square_feet   lot_size year_built  \
# ...

# %%
redfin_east_coast['hoa_permonth'] = redfin_east_coast['hoa_permonth'].fillna(0)

# %%
redfin_east_coast['lot_size'] = redfin_east_coast['lot_size'].fillna(0)

# %%
redfin_east_coast['beds'] = redfin_east_coast['beds'].fillna(0)

# %%
redfin_east_coast['baths'] = redfin_east_coast['baths'].fillna(0)

# %%
redfin_east_coast['square_feet'] = redfin_east_coast['square_feet'].fillna(0)

# %%
redfin_east_coast['year_built'] = redfin_east_coast['year_built'].fillna('unknown')

# %%
redfin_east_coast_dropna = redfin_east_coast.dropna()
redfin_east_coast_dropna
# Out:
#                   property_type                address       city state  \
# 0     Single Family Residential           21 Grimes St     Boston    MA
# 1                   Condo/Co-op        16 Mystic St #2     Boston    MA
# 2                   Condo/Co-op  146 Marlborough St #1     Boston    MA
# 3                   Condo/Co-op     1 Howard Pl Unit C     Boston    MA
# 4                   Condo/Co-op    43 Park Vale Ave #7     Boston    MA
# ...                         ...                    ...        ...   ...
# 4404  Single Family Residential          55 Perkins Rd  Greenwich    CT
# 4405  Single Family Residential      586 Round Hill Rd  Greenwich    CT
# 4406  Single Family Residential    1233 Rock Rimmon Rd   Stamford    CT
# 4407  Single Family Residential     1111 Sasco Hill Rd  Fairfield    CT
# 4408  Single Family Residential         18 Wallacks Dr   Stamford    CT
#
#       zip_code       price  beds  baths  square_feet   lot_size year_built  \
# ...

# %%
east_coast_new_index = redfin_east_coast_dropna.reset_index(drop=True)

# %%
east_coast_new_index
# Out:
#                   property_type                address       city state  \
# 0     Single Family Residential           21 Grimes St     Boston    MA
# 1                   Condo/Co-op        16 Mystic St #2     Boston    MA
# 2                   Condo/Co-op  146 Marlborough St #1     Boston    MA
# 3                   Condo/Co-op     1 Howard Pl Unit C     Boston    MA
# 4                   Condo/Co-op    43 Park Vale Ave #7     Boston    MA
# ...                         ...                    ...        ...   ...
# 4371  Single Family Residential          55 Perkins Rd  Greenwich    CT
# 4372  Single Family Residential      586 Round Hill Rd  Greenwich    CT
# 4373  Single Family Residential    1233 Rock Rimmon Rd   Stamford    CT
# 4374  Single Family Residential     1111 Sasco Hill Rd  Fairfield    CT
# 4375  Single Family Residential         18 Wallacks Dr   Stamford    CT
#
#       zip_code       price  beds  baths  square_feet   lot_size year_built  \
# ...

# %%
east_coast_new_index.to_csv('redfin_resources/combined_regions/redfin_eastcoast_combined.csv')
