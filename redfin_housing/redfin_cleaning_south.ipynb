# %%
import pandas as pd
import numpy as np

# %%
alabama_redfin = pd.read_csv("redfin_south/alabama_redfin.csv")

# %%
alabama_redfin.head()
# Out:
#                PROPERTY TYPE           ADDRESS            CITY  \
# 0  Single Family Residential  832 Southbend Ln  Vestavia Hills
# 1  Single Family Residential  833 Southbend Ln  Vestavia Hills
# 2  Single Family Residential  829 Southbend Ln  Vestavia Hills
# 3  Single Family Residential  Lot 3 Sunset Rdg        Homewood
# 4  Single Family Residential       3784 Poe Dr  Vestavia Hills
#
#   STATE OR PROVINCE  ZIP OR POSTAL CODE   PRICE  BEDS  BATHS  SQUARE FEET  \
# 0                AL               35243  650000     3    2.5          NaN
# 1                AL               35243  650000     3    2.5          NaN
# 2                AL               35243  650000     3    2.5          NaN
# 3                AL               35226  449500     4    3.0       2180.0
# 4                AL               35223  789900     5    4.0       3305.0
#
#    LOT SIZE  YEAR BUILT  HOA/MONTH  \
# 0    9147.0      2020.0         67
# 1   15681.0      2020.0         67
# ...

# %%
alabama_renamed = alabama_redfin.rename(columns={"PROPERTY TYPE": "property_type", "ADDRESS": "address", "CITY":"city", "STATE OR PROVINCE":"state",
                             "ZIP OR POSTAL CODE":"zip_code", "PRICE":"price", "BEDS":"beds", "BATHS":"baths",
                             "SQUARE FEET":"square_feet", "LOT SIZE":'lot_size', 
                              "YEAR BUILT":"year_built", "HOA/MONTH":"hoa_permonth", 
                              "URL (SEE http://www.redfin.com/buy-a-home/comparative-market-analysis FOR INFO ON PRICING)":"url",
                              "LATITUDE":"latitude", "LONGITUDE":"longitude"})

# %%
alabama_renamed.head()
# Out:
#                property_type           address            city state  \
# 0  Single Family Residential  832 Southbend Ln  Vestavia Hills    AL
# 1  Single Family Residential  833 Southbend Ln  Vestavia Hills    AL
# 2  Single Family Residential  829 Southbend Ln  Vestavia Hills    AL
# 3  Single Family Residential  Lot 3 Sunset Rdg        Homewood    AL
# 4  Single Family Residential       3784 Poe Dr  Vestavia Hills    AL
#
#    zip_code   price  beds  baths  square_feet  lot_size  year_built  \
# 0     35243  650000     3    2.5          NaN    9147.0      2020.0
# 1     35243  650000     3    2.5          NaN   15681.0      2020.0
# 2     35243  650000     3    2.5          NaN   28749.0      2020.0
# 3     35226  449500     4    3.0       2180.0   18730.0      2020.0
# 4     35223  789900     5    4.0       3305.0    6969.0      2020.0
#
#    hoa_permonth                                                url   latitude  \
# ...

# %%
alabama_renamed.to_csv("redfin_resources/combined_regions/redfin_south.csv")
