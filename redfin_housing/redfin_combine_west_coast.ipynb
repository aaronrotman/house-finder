# %%
import pandas as pd
import numpy as np

# %%
boise_id = pd.read_csv("redfin_resources/redfin_boise_id.csv")
losangeles_ca = pd.read_csv("redfin_resources/redfin_losangeles_ca.csv")
seattle_wa = pd.read_csv("redfin_resources/redfin_seattle_wa.csv")
portlan_or = pd.read_csv("redfin_resources/redfin_portlan_or.csv")
sanfrancisco_ca = pd.read_csv("redfin_resources/redfin_sanfrancisco_ca.csv")
lasvegas_nv = pd.read_csv("redfin_resources/redfin_lasvegas_nv.csv")
sandiego_ca = pd.read_csv("redfin_resources/redfin_sandiego_ca.csv")
alaska = pd.read_csv("redfin_resources/alaska_all.csv")
arizona = pd.read_csv("redfin_resources/arizona_all.csv")

# %%
arizona.head()
# Out:
#    Unnamed: 0              property_type                       address  \
# 0           0  Single Family Residential        3755 W Strawberry Roan
# 1           1  Single Family Residential         2109 AMIEL WHIPPLE St
# 2           2                  Townhouse        4005 S Lake Mary Rd #4
# 3           3  Single Family Residential      1913 Bessie Kidd Best --
# 4           4                Condo/Co-op  3200 S Litzler Dr Unit 7-129
#
#         city state  zip_code      price  beds  baths  square_feet  lot_size  \
# 0  Flagstaff    AZ   86005.0   749900.0   3.0    2.5       2308.0    2400.0
# 1  Flagstaff    AZ   86005.0  1199000.0   4.0    4.5       3200.0   18295.0
# 2  Flagstaff    AZ   86005.0   260000.0   2.0    2.5       1275.0     793.0
# 3  Flagstaff    AZ   86005.0  2650000.0   4.0    4.5       5557.0   55321.0
# 4  Flagstaff    AZ   86005.0   169000.0   1.0    1.0        562.0     435.0
#
#   year_built  hoa_permonth                                                url  \
# ...

# %%
boise_id.head(2)
# Out:
#    Unnamed: 0              property_type             address   city state  \
# 0           0  Single Family Residential      2100 N 17th St  Boise    ID
# 1           1  Single Family Residential  4797 Arrowhead Way  Boise    ID
#
#   zip_code   price  beds  baths  square_feet  lot_size  year_built  \
# 0    83702  899000     3    2.5         2500    6098.0        2020
# 1    83709  268900     3    1.0         1127    9583.0        1982
#
#    hoa_permonth                                                url   latitude  \
# 0           NaN  http://www.redfin.com/ID/Boise/2100-N-17th-St-...  43.639235
# 1           NaN  http://www.redfin.com/ID/Boise/4797-Arrowhead-...  43.559434
#
#     longitude
# 0 -116.209058
# 1 -116.276367

# %%
frames = [boise_id, losangeles_ca, sandiego_ca, sanfrancisco_ca, lasvegas_nv, portlan_or, seattle_wa, alaska, arizona]
redfin_west_coast_combine = pd.concat(frames, ignore_index=True)

# %%
redfin_west_coast_combine
# Out:
#       Unnamed: 0              property_type                   address  \
# 0              0  Single Family Residential            2100 N 17th St
# 1              1  Single Family Residential        4797 Arrowhead Way
# 2              2  Single Family Residential  12572 W Hidden Valley Dr
# 3              3  Single Family Residential            547 E Orion Ct
# 4              4                  Townhouse      5883 S Blue Nile Ave
# ...          ...                        ...                       ...
# 6406        3305                Condo/Co-op       805 N 4TH Ave #1102
# 6407        3306                Condo/Co-op        805 N 4TH Ave #202
# 6408        3307                Condo/Co-op        805 N 4TH Ave #908
# 6409        3308  Single Family Residential          101 W GRANADA Rd
# 6410        3309  Single Family Residential         502 W WILSHIRE Dr
#
#          city state zip_code      price  beds  baths  square_feet  lot_size  \
# ...

# %%
redfin_west_coast = redfin_west_coast_combine.drop(columns=['Unnamed: 0'])

# %%
redfin_west_coast
# Out:
#                   property_type                   address     city state  \
# 0     Single Family Residential            2100 N 17th St    Boise    ID
# 1     Single Family Residential        4797 Arrowhead Way    Boise    ID
# 2     Single Family Residential  12572 W Hidden Valley Dr    Boise    ID
# 3     Single Family Residential            547 E Orion Ct    Boise    ID
# 4                     Townhouse      5883 S Blue Nile Ave    Boise    ID
# ...                         ...                       ...      ...   ...
# 6406                Condo/Co-op       805 N 4TH Ave #1102  Phoenix    AZ
# 6407                Condo/Co-op        805 N 4TH Ave #202  Phoenix    AZ
# 6408                Condo/Co-op        805 N 4TH Ave #908  Phoenix    AZ
# 6409  Single Family Residential          101 W GRANADA Rd  Phoenix    AZ
# 6410  Single Family Residential         502 W WILSHIRE Dr  Phoenix    AZ
#
#      zip_code      price  beds  baths  square_feet  lot_size year_built  \
# ...

# %%
redfin_west_coast['hoa_permonth'] = redfin_west_coast['hoa_permonth'].fillna(0)

# %%
redfin_west_coast['lot_size'] = redfin_west_coast['lot_size'].fillna(0)

# %%
redfin_west_coast['beds'] = redfin_west_coast['beds'].fillna(0)

# %%
redfin_west_coast['baths'] = redfin_west_coast['baths'].fillna(0)

# %%
redfin_west_coast['square_feet'] = redfin_west_coast['square_feet'].fillna(0)

# %%
redfin_west_coast['year_built'] = redfin_west_coast['year_built'].fillna('unknown')

# %%
redfin_west_coast_dropna = redfin_west_coast.dropna()
redfin_west_coast_dropna
# Out:
#                   property_type                   address     city state  \
# 0     Single Family Residential            2100 N 17th St    Boise    ID
# 1     Single Family Residential        4797 Arrowhead Way    Boise    ID
# 2     Single Family Residential  12572 W Hidden Valley Dr    Boise    ID
# 3     Single Family Residential            547 E Orion Ct    Boise    ID
# 4                     Townhouse      5883 S Blue Nile Ave    Boise    ID
# ...                         ...                       ...      ...   ...
# 6406                Condo/Co-op       805 N 4TH Ave #1102  Phoenix    AZ
# 6407                Condo/Co-op        805 N 4TH Ave #202  Phoenix    AZ
# 6408                Condo/Co-op        805 N 4TH Ave #908  Phoenix    AZ
# 6409  Single Family Residential          101 W GRANADA Rd  Phoenix    AZ
# 6410  Single Family Residential         502 W WILSHIRE Dr  Phoenix    AZ
#
#      zip_code      price  beds  baths  square_feet  lot_size year_built  \
# ...

# %%
west_coast_new_index = redfin_west_coast_dropna.reset_index(drop=True)

# %%
west_coast_new_index
# Out:
#                   property_type                   address     city state  \
# 0     Single Family Residential            2100 N 17th St    Boise    ID
# 1     Single Family Residential        4797 Arrowhead Way    Boise    ID
# 2     Single Family Residential  12572 W Hidden Valley Dr    Boise    ID
# 3     Single Family Residential            547 E Orion Ct    Boise    ID
# 4                     Townhouse      5883 S Blue Nile Ave    Boise    ID
# ...                         ...                       ...      ...   ...
# 6395                Condo/Co-op       805 N 4TH Ave #1102  Phoenix    AZ
# 6396                Condo/Co-op        805 N 4TH Ave #202  Phoenix    AZ
# 6397                Condo/Co-op        805 N 4TH Ave #908  Phoenix    AZ
# 6398  Single Family Residential          101 W GRANADA Rd  Phoenix    AZ
# 6399  Single Family Residential         502 W WILSHIRE Dr  Phoenix    AZ
#
#      zip_code      price  beds  baths  square_feet  lot_size year_built  \
# ...

# %%
west_coast_new_index.to_csv('redfin_resources/combined_regions/redfin_westcoast_combined.csv')
