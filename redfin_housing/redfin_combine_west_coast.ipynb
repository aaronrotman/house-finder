# %%
import pandas as pd
import numpy as np

# %%
boise_id = pd.read_csv("redfin_resources/redfin_boise_id.csv")
losangeles_ca = pd.read_csv("redfin_resources/redfin_losangeles_ca.csv")
seattle_wa = pd.read_csv("redfin_resources/redfin_seattle_wa.csv")
portlan_or = pd.read_csv("redfin_resources/redfin_portlan_or.csv")
sanfrancisco_ca = pd.read_csv("redfin_resources/redfin_sanfrancisco_ca.csv")
lasvegas_nv = pd.read_csv("redfin_resources/redfin_lasvegas_nv.csv")
sandiego_ca = pd.read_csv("redfin_resources/redfin_sandiego_ca.csv")

# %%
boise_id.head(2)
# Out:
#    Unnamed: 0              property_type             address   city state  \
# 0           0  Single Family Residential      2100 N 17th St  Boise    ID
# 1           1  Single Family Residential  4797 Arrowhead Way  Boise    ID
#
#   zip_code   price  beds  baths  square_feet  lot_size  year_built  \
# 0    83702  899000   3.0    2.5       2500.0    6098.0      2020.0
# 1    83709  268900   3.0    1.0       1127.0    9583.0      1982.0
#
#    hoa_permonth                                                url   latitude  \
# 0           NaN  http://www.redfin.com/ID/Boise/2100-N-17th-St-...  43.639235
# 1           NaN  http://www.redfin.com/ID/Boise/4797-Arrowhead-...  43.559434
#
#     longitude
# 0 -116.209058
# 1 -116.276367

# %%
frames = [boise_id, losangeles_ca, sandiego_ca, sanfrancisco_ca, lasvegas_nv, portlan_or, seattle_wa]
redfin_west_coast_combine = pd.concat(frames, ignore_index=True)

# %%
redfin_west_coast_combine
# Out:
#       Unnamed: 0              property_type                    address  \
# 0              0  Single Family Residential             2100 N 17th St
# 1              1  Single Family Residential         4797 Arrowhead Way
# 2              2                Vacant Land             747 E Orion Dr
# 3              3  Single Family Residential   12572 W Hidden Valley Dr
# 4              4  Single Family Residential             547 E Orion Ct
# ...          ...                        ...                        ...
# 2445         345  Single Family Residential            2837 12th Ave W
# 2446         346  Single Family Residential            5527 56th Ave S
# 2447         347  Single Family Residential            1904 24TH Ave S
# 2448         348  Single Family Residential             4610 S Gazelle
# 2449         349                  Townhouse  2705 SW Sylvan Heights Dr
#
#          city state zip_code      price  beds  baths  square_feet  lot_size  \
# 0       Boise    ID    83702   899000.0   3.0   2.50       2500.0    6098.0
# 1       Boise    ID    83709   268900.0   3.0   1.00       1127.0    9583.0
# 2       Boise    ID    83702   400000.0   NaN    NaN          NaN   15681.0
# 3       Boise    ID    83709   359000.0   3.0   2.00       2008.0    8712.0
# 4       Boise    ID    83702  2490000.0   5.0   4.50       4695.0   25351.0
# ...       ...   ...      ...        ...   ...    ...          ...       ...
# 2445  Seattle    WA    98119   998888.0   4.0   1.75       1820.0    5800.0
# 2446  Seattle    WA    98118   998000.0   5.0   2.75       2860.0    5000.0
# 2447  Seattle    WA    98144   719000.0   3.0   2.25       1450.0     824.0
# 2448  Seattle    WA    98118   515000.0   3.0   2.00       1550.0    5500.0
# 2449  Seattle    WA    98106   515000.0   2.0   2.25       1420.0    1245.0
#
#       year_built  hoa_permonth  \
# 0         2020.0           NaN
# 1         1982.0           NaN
# 2            NaN         103.0
# 3         2006.0          28.0
# 4         2007.0         117.0
# ...          ...           ...
# 2445      1946.0           NaN
# 2446      1929.0           NaN
# 2447      2016.0         100.0
# 2448      1957.0           NaN
# 2449      2007.0         190.0
#
#                                                     url   latitude   longitude
# 0     http://www.redfin.com/ID/Boise/2100-N-17th-St-...  43.639235 -116.209058
# 1     http://www.redfin.com/ID/Boise/4797-Arrowhead-...  43.559434 -116.276367
# 2     http://www.redfin.com/ID/Boise/747-E-Orion-Dr-...  43.637653 -116.180297
# 3     http://www.redfin.com/ID/Boise/12572-W-Hidden-...  43.537023 -116.338323
# 4     http://www.redfin.com/ID/Boise/547-E-Orion-Ct-...  43.636705 -116.183007
# ...                                                 ...        ...         ...
# 2445  http://www.redfin.com/WA/Seattle/2837-12th-Ave...  47.646284 -122.372816
# 2446  http://www.redfin.com/WA/Seattle/5527-56th-Ave...  47.551760 -122.263683
# 2447  http://www.redfin.com/WA/Seattle/1904-24th-Ave...  47.586149 -122.301390
# 2448  http://www.redfin.com/WA/Seattle/4610-S-Gazell...  47.512701 -122.274848
# 2449  http://www.redfin.com/WA/Seattle/2705-SW-Sylva...  47.539596 -122.368164
#
# [2450 rows x 16 columns]

# %%
redfin_west_coast = redfin_west_coast_combine.drop(columns=['Unnamed: 0'])

# %%
redfin_west_coast
# Out:
#                   property_type                    address     city state  \
# 0     Single Family Residential             2100 N 17th St    Boise    ID
# 1     Single Family Residential         4797 Arrowhead Way    Boise    ID
# 2                   Vacant Land             747 E Orion Dr    Boise    ID
# 3     Single Family Residential   12572 W Hidden Valley Dr    Boise    ID
# 4     Single Family Residential             547 E Orion Ct    Boise    ID
# ...                         ...                        ...      ...   ...
# 2445  Single Family Residential            2837 12th Ave W  Seattle    WA
# 2446  Single Family Residential            5527 56th Ave S  Seattle    WA
# 2447  Single Family Residential            1904 24TH Ave S  Seattle    WA
# 2448  Single Family Residential             4610 S Gazelle  Seattle    WA
# 2449                  Townhouse  2705 SW Sylvan Heights Dr  Seattle    WA
#
#      zip_code      price  beds  baths  square_feet  lot_size  year_built  \
# 0       83702   899000.0   3.0   2.50       2500.0    6098.0      2020.0
# 1       83709   268900.0   3.0   1.00       1127.0    9583.0      1982.0
# 2       83702   400000.0   NaN    NaN          NaN   15681.0         NaN
# 3       83709   359000.0   3.0   2.00       2008.0    8712.0      2006.0
# 4       83702  2490000.0   5.0   4.50       4695.0   25351.0      2007.0
# ...       ...        ...   ...    ...          ...       ...         ...
# 2445    98119   998888.0   4.0   1.75       1820.0    5800.0      1946.0
# 2446    98118   998000.0   5.0   2.75       2860.0    5000.0      1929.0
# 2447    98144   719000.0   3.0   2.25       1450.0     824.0      2016.0
# 2448    98118   515000.0   3.0   2.00       1550.0    5500.0      1957.0
# 2449    98106   515000.0   2.0   2.25       1420.0    1245.0      2007.0
#
#       hoa_permonth                                                url  \
# 0              NaN  http://www.redfin.com/ID/Boise/2100-N-17th-St-...
# 1              NaN  http://www.redfin.com/ID/Boise/4797-Arrowhead-...
# 2            103.0  http://www.redfin.com/ID/Boise/747-E-Orion-Dr-...
# 3             28.0  http://www.redfin.com/ID/Boise/12572-W-Hidden-...
# 4            117.0  http://www.redfin.com/ID/Boise/547-E-Orion-Ct-...
# ...            ...                                                ...
# 2445           NaN  http://www.redfin.com/WA/Seattle/2837-12th-Ave...
# 2446           NaN  http://www.redfin.com/WA/Seattle/5527-56th-Ave...
# 2447         100.0  http://www.redfin.com/WA/Seattle/1904-24th-Ave...
# 2448           NaN  http://www.redfin.com/WA/Seattle/4610-S-Gazell...
# 2449         190.0  http://www.redfin.com/WA/Seattle/2705-SW-Sylva...
#
#        latitude   longitude
# 0     43.639235 -116.209058
# 1     43.559434 -116.276367
# 2     43.637653 -116.180297
# 3     43.537023 -116.338323
# 4     43.636705 -116.183007
# ...         ...         ...
# 2445  47.646284 -122.372816
# 2446  47.551760 -122.263683
# 2447  47.586149 -122.301390
# 2448  47.512701 -122.274848
# 2449  47.539596 -122.368164
#
# [2450 rows x 15 columns]

# %%
redfin_west_coast['hoa_permonth'] = redfin_west_coast['hoa_permonth'].fillna(0)

# %%
redfin_west_coast['lot_size'] = redfin_west_coast['lot_size'].fillna(0)

# %%
redfin_west_coast['beds'] = redfin_west_coast['beds'].fillna(0)

# %%
redfin_west_coast['baths'] = redfin_west_coast['baths'].fillna(0)

# %%
redfin_west_coast['square_feet'] = redfin_west_coast['square_feet'].fillna(0)

# %%
redfin_west_coast['year_built'] = redfin_west_coast['year_built'].fillna('unknown')

# %%
redfin_west_coast_dropna = redfin_west_coast.dropna()
redfin_west_coast_dropna
# Out:
#                   property_type                    address     city state  \
# 0     Single Family Residential             2100 N 17th St    Boise    ID
# 1     Single Family Residential         4797 Arrowhead Way    Boise    ID
# 2                   Vacant Land             747 E Orion Dr    Boise    ID
# 3     Single Family Residential   12572 W Hidden Valley Dr    Boise    ID
# 4     Single Family Residential             547 E Orion Ct    Boise    ID
# ...                         ...                        ...      ...   ...
# 2445  Single Family Residential            2837 12th Ave W  Seattle    WA
# 2446  Single Family Residential            5527 56th Ave S  Seattle    WA
# 2447  Single Family Residential            1904 24TH Ave S  Seattle    WA
# 2448  Single Family Residential             4610 S Gazelle  Seattle    WA
# 2449                  Townhouse  2705 SW Sylvan Heights Dr  Seattle    WA
#
#      zip_code      price  beds  baths  square_feet  lot_size year_built  \
# 0       83702   899000.0   3.0   2.50       2500.0    6098.0       2020
# 1       83709   268900.0   3.0   1.00       1127.0    9583.0       1982
# 2       83702   400000.0   0.0   0.00          0.0   15681.0    unknown
# 3       83709   359000.0   3.0   2.00       2008.0    8712.0       2006
# 4       83702  2490000.0   5.0   4.50       4695.0   25351.0       2007
# ...       ...        ...   ...    ...          ...       ...        ...
# 2445    98119   998888.0   4.0   1.75       1820.0    5800.0       1946
# 2446    98118   998000.0   5.0   2.75       2860.0    5000.0       1929
# 2447    98144   719000.0   3.0   2.25       1450.0     824.0       2016
# 2448    98118   515000.0   3.0   2.00       1550.0    5500.0       1957
# 2449    98106   515000.0   2.0   2.25       1420.0    1245.0       2007
#
#       hoa_permonth                                                url  \
# 0              0.0  http://www.redfin.com/ID/Boise/2100-N-17th-St-...
# 1              0.0  http://www.redfin.com/ID/Boise/4797-Arrowhead-...
# 2            103.0  http://www.redfin.com/ID/Boise/747-E-Orion-Dr-...
# 3             28.0  http://www.redfin.com/ID/Boise/12572-W-Hidden-...
# 4            117.0  http://www.redfin.com/ID/Boise/547-E-Orion-Ct-...
# ...            ...                                                ...
# 2445           0.0  http://www.redfin.com/WA/Seattle/2837-12th-Ave...
# 2446           0.0  http://www.redfin.com/WA/Seattle/5527-56th-Ave...
# 2447         100.0  http://www.redfin.com/WA/Seattle/1904-24th-Ave...
# 2448           0.0  http://www.redfin.com/WA/Seattle/4610-S-Gazell...
# 2449         190.0  http://www.redfin.com/WA/Seattle/2705-SW-Sylva...
#
#        latitude   longitude
# 0     43.639235 -116.209058
# 1     43.559434 -116.276367
# 2     43.637653 -116.180297
# 3     43.537023 -116.338323
# 4     43.636705 -116.183007
# ...         ...         ...
# 2445  47.646284 -122.372816
# 2446  47.551760 -122.263683
# 2447  47.586149 -122.301390
# 2448  47.512701 -122.274848
# 2449  47.539596 -122.368164
#
# [2435 rows x 15 columns]

# %%
west_coast_new_index = redfin_west_coast_dropna.reset_index(drop=True)

# %%
west_coast_new_index
# Out:
#                   property_type                    address     city state  \
# 0     Single Family Residential             2100 N 17th St    Boise    ID
# 1     Single Family Residential         4797 Arrowhead Way    Boise    ID
# 2                   Vacant Land             747 E Orion Dr    Boise    ID
# 3     Single Family Residential   12572 W Hidden Valley Dr    Boise    ID
# 4     Single Family Residential             547 E Orion Ct    Boise    ID
# ...                         ...                        ...      ...   ...
# 2430  Single Family Residential            2837 12th Ave W  Seattle    WA
# 2431  Single Family Residential            5527 56th Ave S  Seattle    WA
# 2432  Single Family Residential            1904 24TH Ave S  Seattle    WA
# 2433  Single Family Residential             4610 S Gazelle  Seattle    WA
# 2434                  Townhouse  2705 SW Sylvan Heights Dr  Seattle    WA
#
#      zip_code      price  beds  baths  square_feet  lot_size year_built  \
# 0       83702   899000.0   3.0   2.50       2500.0    6098.0       2020
# 1       83709   268900.0   3.0   1.00       1127.0    9583.0       1982
# 2       83702   400000.0   0.0   0.00          0.0   15681.0    unknown
# 3       83709   359000.0   3.0   2.00       2008.0    8712.0       2006
# 4       83702  2490000.0   5.0   4.50       4695.0   25351.0       2007
# ...       ...        ...   ...    ...          ...       ...        ...
# 2430    98119   998888.0   4.0   1.75       1820.0    5800.0       1946
# 2431    98118   998000.0   5.0   2.75       2860.0    5000.0       1929
# 2432    98144   719000.0   3.0   2.25       1450.0     824.0       2016
# 2433    98118   515000.0   3.0   2.00       1550.0    5500.0       1957
# 2434    98106   515000.0   2.0   2.25       1420.0    1245.0       2007
#
#       hoa_permonth                                                url  \
# 0              0.0  http://www.redfin.com/ID/Boise/2100-N-17th-St-...
# 1              0.0  http://www.redfin.com/ID/Boise/4797-Arrowhead-...
# 2            103.0  http://www.redfin.com/ID/Boise/747-E-Orion-Dr-...
# 3             28.0  http://www.redfin.com/ID/Boise/12572-W-Hidden-...
# 4            117.0  http://www.redfin.com/ID/Boise/547-E-Orion-Ct-...
# ...            ...                                                ...
# 2430           0.0  http://www.redfin.com/WA/Seattle/2837-12th-Ave...
# 2431           0.0  http://www.redfin.com/WA/Seattle/5527-56th-Ave...
# 2432         100.0  http://www.redfin.com/WA/Seattle/1904-24th-Ave...
# 2433           0.0  http://www.redfin.com/WA/Seattle/4610-S-Gazell...
# 2434         190.0  http://www.redfin.com/WA/Seattle/2705-SW-Sylva...
#
#        latitude   longitude
# 0     43.639235 -116.209058
# 1     43.559434 -116.276367
# 2     43.637653 -116.180297
# 3     43.537023 -116.338323
# 4     43.636705 -116.183007
# ...         ...         ...
# 2430  47.646284 -122.372816
# 2431  47.551760 -122.263683
# 2432  47.586149 -122.301390
# 2433  47.512701 -122.274848
# 2434  47.539596 -122.368164
#
# [2435 rows x 15 columns]

# %%
midwest_new_index.to_csv('redfin_resources/combined_regions/redfin_midwest_combined.csv')
