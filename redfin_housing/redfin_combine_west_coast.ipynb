# %%
import pandas as pd
import numpy as np

# %%
boise_id = pd.read_csv("redfin_resources/redfin_boise_id.csv")
losangeles_ca = pd.read_csv("redfin_resources/redfin_losangeles_ca.csv")
seattle_wa = pd.read_csv("redfin_resources/redfin_seattle_wa.csv")
portlan_or = pd.read_csv("redfin_resources/redfin_portlan_or.csv")
sanfrancisco_ca = pd.read_csv("redfin_resources/redfin_sanfrancisco_ca.csv")
lasvegas_nv = pd.read_csv("redfin_resources/redfin_lasvegas_nv.csv")
sandiego_ca = pd.read_csv("redfin_resources/redfin_sandiego_ca.csv")
alaska = pd.read_csv("redfin_resources/alaska_all.csv")

# %%
alaska.head()
# Out:
#    Unnamed: 0              property_type                address          city  \
# 0           0  Single Family Residential  32996 Heather Glen Ct  Anchor Point
# 1           1  Single Family Residential      70875 Lee Roy Ave  Anchor Point
# 2           2  Single Family Residential     26890 Sterling Hwy  Anchor Point
# 3           3  Single Family Residential     31513 Sterling Hwy  Anchor Point
# 4           4  Single Family Residential        72960 Laida Ave  Anchor Point
#
#   state  zip_code     price  beds  baths  square_feet  lot_size  year_built  \
# 0    AK   99556.0  369900.0   5.0    3.0       2500.0  404672.0      2016.0
# 1    AK   99556.0  319000.0   2.0    2.0       1456.0  125452.0      2002.0
# 2    AK   99556.0  115000.0   2.0    1.0        896.0   86248.0      2009.0
# 3    AK   99556.0  205000.0   3.0    1.0       1423.0   78408.0      1962.0
# 4    AK   99556.0  299000.0   2.0    2.0       2185.0   78843.0      1998.0
#
#    hoa_permonth                                                url   latitude  \
# 0           0.0  http://www.redfin.com/AK/Unknown/32996-HEATHER...  59.794550
# 1           0.0  http://www.redfin.com/AK/Anchor-Point/70875-Le...  59.845004
# 2           0.0  http://www.redfin.com/AK/Anchor-Point/26890-St...  59.882706
# 3           0.0  http://www.redfin.com/AK/Anchor-Point/31513-St...  59.816224
# 4           0.0  http://www.redfin.com/AK/Anchor-Point/72960-La...  59.781840
#
#     longitude
# 0 -151.827787
# 1 -151.787534
# 2 -151.782732
# 3 -151.827229
# 4 -151.851596

# %%
boise_id.head(2)
# Out:
#    Unnamed: 0              property_type             address   city state  \
# 0           0  Single Family Residential      2100 N 17th St  Boise    ID
# 1           1  Single Family Residential  4797 Arrowhead Way  Boise    ID
#
#   zip_code   price  beds  baths  square_feet  lot_size  year_built  \
# 0    83702  899000   3.0    2.5       2500.0    6098.0      2020.0
# 1    83709  268900   3.0    1.0       1127.0    9583.0      1982.0
#
#    hoa_permonth                                                url   latitude  \
# 0           NaN  http://www.redfin.com/ID/Boise/2100-N-17th-St-...  43.639235
# 1           NaN  http://www.redfin.com/ID/Boise/4797-Arrowhead-...  43.559434
#
#     longitude
# 0 -116.209058
# 1 -116.276367

# %%
frames = [boise_id, losangeles_ca, sandiego_ca, sanfrancisco_ca, lasvegas_nv, portlan_or, seattle_wa, alaska]
redfin_west_coast_combine = pd.concat(frames, ignore_index=True)

# %%
redfin_west_coast_combine
# Out:
#       Unnamed: 0              property_type                   address    city  \
# 0              0  Single Family Residential            2100 N 17th St   Boise
# 1              1  Single Family Residential        4797 Arrowhead Way   Boise
# 2              2                Vacant Land            747 E Orion Dr   Boise
# 3              3  Single Family Residential  12572 W Hidden Valley Dr   Boise
# 4              4  Single Family Residential            547 E Orion Ct   Boise
# ...          ...                        ...                       ...     ...
# 3482        1032  Single Family Residential               Tr 98 No Rd  Willow
# 3483        1033  Single Family Residential           24385 W Wade Dr  Willow
# 3484        1034  Single Family Residential       14168 N Michigan ST  Willow
# 3485        1035  Single Family Residential  48950 S Silver Salmon Dr  Willow
# 3486        1036  Single Family Residential   48610 S Dolly Varden Dr  Willow
#
#      state zip_code      price  beds  baths  square_feet  lot_size  \
# 0       ID    83702   899000.0   3.0    2.5       2500.0    6098.0
# 1       ID    83709   268900.0   3.0    1.0       1127.0    9583.0
# 2       ID    83702   400000.0   NaN    NaN          NaN   15681.0
# 3       ID    83709   359000.0   3.0    2.0       2008.0    8712.0
# 4       ID    83702  2490000.0   5.0    4.5       4695.0   25351.0
# ...    ...      ...        ...   ...    ...          ...       ...
# 3482    AK    99688   139000.0   2.0    1.0       1100.0   80586.0
# 3483    AK    99688    28500.0   0.0    NaN        264.0   24393.0
# 3484    AK    99688   349000.0   3.0    2.0       1700.0   44431.0
# 3485    AK    99688   200000.0   3.0    3.0       2300.0   31363.0
# 3486    AK    99688    13900.0   0.0    NaN         64.0   31363.0
#
#       year_built  hoa_permonth  \
# 0         2020.0           NaN
# 1         1982.0           NaN
# 2            NaN         103.0
# 3         2006.0          28.0
# 4         2007.0         117.0
# ...          ...           ...
# 3482      1991.0           0.0
# 3483      1994.0           0.0
# 3484      1999.0           0.0
# 3485      2019.0           0.0
# 3486      2020.0           0.0
#
#                                                     url   latitude   longitude
# 0     http://www.redfin.com/ID/Boise/2100-N-17th-St-...  43.639235 -116.209058
# 1     http://www.redfin.com/ID/Boise/4797-Arrowhead-...  43.559434 -116.276367
# 2     http://www.redfin.com/ID/Boise/747-E-Orion-Dr-...  43.637653 -116.180297
# 3     http://www.redfin.com/ID/Boise/12572-W-Hidden-...  43.537023 -116.338323
# 4     http://www.redfin.com/ID/Boise/547-E-Orion-Ct-...  43.636705 -116.183007
# ...                                                 ...        ...         ...
# 3482  http://www.redfin.com/AK/Willow/Tr-98-No-RD-99...  61.985855 -149.464753
# 3483  http://www.redfin.com/AK/Willow/24385-W-Wade-D...  61.771445 -150.064428
# 3484  http://www.redfin.com/AK/Willow/14168-N-Michig...  61.747223 -150.037506
# 3485  http://www.redfin.com/AK/Willow/48950-S-Silver...  62.000748 -149.960235
# 3486  http://www.redfin.com/AK/WILLOW/48610-S-DOLLY-...  62.007492 -149.934974
#
# [3487 rows x 16 columns]

# %%
redfin_west_coast = redfin_west_coast_combine.drop(columns=['Unnamed: 0'])

# %%
redfin_west_coast
# Out:
#                   property_type                   address    city state  \
# 0     Single Family Residential            2100 N 17th St   Boise    ID
# 1     Single Family Residential        4797 Arrowhead Way   Boise    ID
# 2                   Vacant Land            747 E Orion Dr   Boise    ID
# 3     Single Family Residential  12572 W Hidden Valley Dr   Boise    ID
# 4     Single Family Residential            547 E Orion Ct   Boise    ID
# ...                         ...                       ...     ...   ...
# 3482  Single Family Residential               Tr 98 No Rd  Willow    AK
# 3483  Single Family Residential           24385 W Wade Dr  Willow    AK
# 3484  Single Family Residential       14168 N Michigan ST  Willow    AK
# 3485  Single Family Residential  48950 S Silver Salmon Dr  Willow    AK
# 3486  Single Family Residential   48610 S Dolly Varden Dr  Willow    AK
#
#      zip_code      price  beds  baths  square_feet  lot_size  year_built  \
# 0       83702   899000.0   3.0    2.5       2500.0    6098.0      2020.0
# 1       83709   268900.0   3.0    1.0       1127.0    9583.0      1982.0
# 2       83702   400000.0   NaN    NaN          NaN   15681.0         NaN
# 3       83709   359000.0   3.0    2.0       2008.0    8712.0      2006.0
# 4       83702  2490000.0   5.0    4.5       4695.0   25351.0      2007.0
# ...       ...        ...   ...    ...          ...       ...         ...
# 3482    99688   139000.0   2.0    1.0       1100.0   80586.0      1991.0
# 3483    99688    28500.0   0.0    NaN        264.0   24393.0      1994.0
# 3484    99688   349000.0   3.0    2.0       1700.0   44431.0      1999.0
# 3485    99688   200000.0   3.0    3.0       2300.0   31363.0      2019.0
# 3486    99688    13900.0   0.0    NaN         64.0   31363.0      2020.0
#
#       hoa_permonth                                                url  \
# 0              NaN  http://www.redfin.com/ID/Boise/2100-N-17th-St-...
# 1              NaN  http://www.redfin.com/ID/Boise/4797-Arrowhead-...
# 2            103.0  http://www.redfin.com/ID/Boise/747-E-Orion-Dr-...
# 3             28.0  http://www.redfin.com/ID/Boise/12572-W-Hidden-...
# 4            117.0  http://www.redfin.com/ID/Boise/547-E-Orion-Ct-...
# ...            ...                                                ...
# 3482           0.0  http://www.redfin.com/AK/Willow/Tr-98-No-RD-99...
# 3483           0.0  http://www.redfin.com/AK/Willow/24385-W-Wade-D...
# 3484           0.0  http://www.redfin.com/AK/Willow/14168-N-Michig...
# 3485           0.0  http://www.redfin.com/AK/Willow/48950-S-Silver...
# 3486           0.0  http://www.redfin.com/AK/WILLOW/48610-S-DOLLY-...
#
#        latitude   longitude
# 0     43.639235 -116.209058
# 1     43.559434 -116.276367
# 2     43.637653 -116.180297
# 3     43.537023 -116.338323
# 4     43.636705 -116.183007
# ...         ...         ...
# 3482  61.985855 -149.464753
# 3483  61.771445 -150.064428
# 3484  61.747223 -150.037506
# 3485  62.000748 -149.960235
# 3486  62.007492 -149.934974
#
# [3487 rows x 15 columns]

# %%
redfin_west_coast['hoa_permonth'] = redfin_west_coast['hoa_permonth'].fillna(0)

# %%
redfin_west_coast['lot_size'] = redfin_west_coast['lot_size'].fillna(0)

# %%
redfin_west_coast['beds'] = redfin_west_coast['beds'].fillna(0)

# %%
redfin_west_coast['baths'] = redfin_west_coast['baths'].fillna(0)

# %%
redfin_west_coast['square_feet'] = redfin_west_coast['square_feet'].fillna(0)

# %%
redfin_west_coast['year_built'] = redfin_west_coast['year_built'].fillna('unknown')

# %%
redfin_west_coast_dropna = redfin_west_coast.dropna()
redfin_west_coast_dropna
# Out:
#                   property_type                   address    city state  \
# 0     Single Family Residential            2100 N 17th St   Boise    ID
# 1     Single Family Residential        4797 Arrowhead Way   Boise    ID
# 2                   Vacant Land            747 E Orion Dr   Boise    ID
# 3     Single Family Residential  12572 W Hidden Valley Dr   Boise    ID
# 4     Single Family Residential            547 E Orion Ct   Boise    ID
# ...                         ...                       ...     ...   ...
# 3482  Single Family Residential               Tr 98 No Rd  Willow    AK
# 3483  Single Family Residential           24385 W Wade Dr  Willow    AK
# 3484  Single Family Residential       14168 N Michigan ST  Willow    AK
# 3485  Single Family Residential  48950 S Silver Salmon Dr  Willow    AK
# 3486  Single Family Residential   48610 S Dolly Varden Dr  Willow    AK
#
#      zip_code      price  beds  baths  square_feet  lot_size year_built  \
# 0       83702   899000.0   3.0    2.5       2500.0    6098.0       2020
# 1       83709   268900.0   3.0    1.0       1127.0    9583.0       1982
# 2       83702   400000.0   0.0    0.0          0.0   15681.0    unknown
# 3       83709   359000.0   3.0    2.0       2008.0    8712.0       2006
# 4       83702  2490000.0   5.0    4.5       4695.0   25351.0       2007
# ...       ...        ...   ...    ...          ...       ...        ...
# 3482    99688   139000.0   2.0    1.0       1100.0   80586.0       1991
# 3483    99688    28500.0   0.0    0.0        264.0   24393.0       1994
# 3484    99688   349000.0   3.0    2.0       1700.0   44431.0       1999
# 3485    99688   200000.0   3.0    3.0       2300.0   31363.0       2019
# 3486    99688    13900.0   0.0    0.0         64.0   31363.0       2020
#
#       hoa_permonth                                                url  \
# 0              0.0  http://www.redfin.com/ID/Boise/2100-N-17th-St-...
# 1              0.0  http://www.redfin.com/ID/Boise/4797-Arrowhead-...
# 2            103.0  http://www.redfin.com/ID/Boise/747-E-Orion-Dr-...
# 3             28.0  http://www.redfin.com/ID/Boise/12572-W-Hidden-...
# 4            117.0  http://www.redfin.com/ID/Boise/547-E-Orion-Ct-...
# ...            ...                                                ...
# 3482           0.0  http://www.redfin.com/AK/Willow/Tr-98-No-RD-99...
# 3483           0.0  http://www.redfin.com/AK/Willow/24385-W-Wade-D...
# 3484           0.0  http://www.redfin.com/AK/Willow/14168-N-Michig...
# 3485           0.0  http://www.redfin.com/AK/Willow/48950-S-Silver...
# 3486           0.0  http://www.redfin.com/AK/WILLOW/48610-S-DOLLY-...
#
#        latitude   longitude
# 0     43.639235 -116.209058
# 1     43.559434 -116.276367
# 2     43.637653 -116.180297
# 3     43.537023 -116.338323
# 4     43.636705 -116.183007
# ...         ...         ...
# 3482  61.985855 -149.464753
# 3483  61.771445 -150.064428
# 3484  61.747223 -150.037506
# 3485  62.000748 -149.960235
# 3486  62.007492 -149.934974
#
# [3467 rows x 15 columns]

# %%
west_coast_new_index = redfin_west_coast_dropna.reset_index(drop=True)

# %%
west_coast_new_index
# Out:
#                   property_type                   address    city state  \
# 0     Single Family Residential            2100 N 17th St   Boise    ID
# 1     Single Family Residential        4797 Arrowhead Way   Boise    ID
# 2                   Vacant Land            747 E Orion Dr   Boise    ID
# 3     Single Family Residential  12572 W Hidden Valley Dr   Boise    ID
# 4     Single Family Residential            547 E Orion Ct   Boise    ID
# ...                         ...                       ...     ...   ...
# 3462  Single Family Residential               Tr 98 No Rd  Willow    AK
# 3463  Single Family Residential           24385 W Wade Dr  Willow    AK
# 3464  Single Family Residential       14168 N Michigan ST  Willow    AK
# 3465  Single Family Residential  48950 S Silver Salmon Dr  Willow    AK
# 3466  Single Family Residential   48610 S Dolly Varden Dr  Willow    AK
#
#      zip_code      price  beds  baths  square_feet  lot_size year_built  \
# 0       83702   899000.0   3.0    2.5       2500.0    6098.0       2020
# 1       83709   268900.0   3.0    1.0       1127.0    9583.0       1982
# 2       83702   400000.0   0.0    0.0          0.0   15681.0    unknown
# 3       83709   359000.0   3.0    2.0       2008.0    8712.0       2006
# 4       83702  2490000.0   5.0    4.5       4695.0   25351.0       2007
# ...       ...        ...   ...    ...          ...       ...        ...
# 3462    99688   139000.0   2.0    1.0       1100.0   80586.0       1991
# 3463    99688    28500.0   0.0    0.0        264.0   24393.0       1994
# 3464    99688   349000.0   3.0    2.0       1700.0   44431.0       1999
# 3465    99688   200000.0   3.0    3.0       2300.0   31363.0       2019
# 3466    99688    13900.0   0.0    0.0         64.0   31363.0       2020
#
#       hoa_permonth                                                url  \
# 0              0.0  http://www.redfin.com/ID/Boise/2100-N-17th-St-...
# 1              0.0  http://www.redfin.com/ID/Boise/4797-Arrowhead-...
# 2            103.0  http://www.redfin.com/ID/Boise/747-E-Orion-Dr-...
# 3             28.0  http://www.redfin.com/ID/Boise/12572-W-Hidden-...
# 4            117.0  http://www.redfin.com/ID/Boise/547-E-Orion-Ct-...
# ...            ...                                                ...
# 3462           0.0  http://www.redfin.com/AK/Willow/Tr-98-No-RD-99...
# 3463           0.0  http://www.redfin.com/AK/Willow/24385-W-Wade-D...
# 3464           0.0  http://www.redfin.com/AK/Willow/14168-N-Michig...
# 3465           0.0  http://www.redfin.com/AK/Willow/48950-S-Silver...
# 3466           0.0  http://www.redfin.com/AK/WILLOW/48610-S-DOLLY-...
#
#        latitude   longitude
# 0     43.639235 -116.209058
# 1     43.559434 -116.276367
# 2     43.637653 -116.180297
# 3     43.537023 -116.338323
# 4     43.636705 -116.183007
# ...         ...         ...
# 3462  61.985855 -149.464753
# 3463  61.771445 -150.064428
# 3464  61.747223 -150.037506
# 3465  62.000748 -149.960235
# 3466  62.007492 -149.934974
#
# [3467 rows x 15 columns]

# %%
west_coast_new_index.to_csv('redfin_resources/combined_regions/redfin_westcoast_combined.csv')
