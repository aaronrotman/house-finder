# %%
import pandas as pd

# %%
midwest_combined_csv = pd.read_csv("redfin_housing/redfin_resources/combined_regions/redfin_midwest_combined.csv")
westcoast_combined_csv = pd.read_csv("redfin_housing/redfin_resources/combined_regions/redfin_westcoast_combined.csv")
east_combined_csv = pd.read_csv("redfin_housing/redfin_resources/combined_regions/redfin_east_coast_combined.csv")

# %%
midwest_combined_csv.head(2)
# Out:
#    Unnamed: 0              property_type             address       city state  \
# 0         459                Vacant Land        000 Avilla E  Alexander    AR
# 1         493  Single Family Residential  9015 Springhill Rd  Alexander    AR
#
#   zip_code   price  beds  baths  square_feet  lot_size year_built  \
# 0    72002  600000     0    0.0            0   2613600    unknown
# 1    72002  175000     5    2.0         2556     69696       1974
#
#    hoa_permonth                                                url   latitude  \
# 0             0  http://www.redfin.com/AR/Beaver-Township/Avill...  34.683729
# 1             0  http://www.redfin.com/AR/Alexander/9015-Spring...  34.673700
#
#    longitude
# 0 -92.581063
# 1 -92.523410

# %%
midwest_combined_csv.city.unique()
# Out:
# array(['Alexander', 'Allenton', 'Bayside', 'Beaver Dam', 'Belgium',
#        'Beloit', 'Benton', 'Bethany', 'Bristol', 'Brookfield',
#        'Brown Deer', 'Brownsville', 'Bryant', 'Campbellsport', 'Cascade',
#        'Cedar Grove', 'Cedarburg', 'Choctaw', 'Clinton', 'Colgate',
#        'Columbus', 'Cudahy', 'Darien', 'Deerfield', 'Del City',
#        'Delafield', 'Delavan', 'Dousman', 'Eagle', 'East Troy',
#        'Edgerton', 'Edmond', 'Elkhorn', 'Fond Du Lac', 'Fontana',
#        'Fort Atkinson', 'Fox Lake', 'Fox Point', 'Franklin', 'Genoa City',
#        'Germantown', 'Glendale', 'Grafton', 'Greenfield', 'Hales Corners',
#        'Hartford', 'Hartland', 'Hubertus', 'Jackson', 'Jacksonville',
#        'Janesville', 'Jefferson', 'Johnson Creek', 'Jones', 'Kansasville',
#        'Kenosha', 'Lake Geneva', 'Lisbon', 'Little Rock', 'Luther',
#        'Mabelvale', 'Maumelle', 'Mayville', 'McLoud', 'Menomonee Falls',
#        'Mequon', 'Milton', 'Milwaukee', 'Moore', 'Mount Pleasant',
# ...

# %%
westcoast_combined_csv.head(2)
# Out:
#    Unnamed: 0              property_type             address   city state  \
# 0           0  Single Family Residential      2100 N 17th St  Boise    ID
# 1           1  Single Family Residential  4797 Arrowhead Way  Boise    ID
#
#   zip_code   price  beds  baths  square_feet  lot_size year_built  \
# 0    83702  899000     3    2.5         2500      6098       2020
# 1    83709  268900     3    1.0         1127      9583       1982
#
#    hoa_permonth                                                url   latitude  \
# 0             0  http://www.redfin.com/ID/Boise/2100-N-17th-St-...  43.639235
# 1             0  http://www.redfin.com/ID/Boise/4797-Arrowhead-...  43.559434
#
#     longitude
# 0 -116.209058
# 1 -116.276367

# %%
westcoast_combined_csv.city.unique()
# Out:
# array(['Boise', 'Meridian', 'Garden City', 'Eagle', 'Chatsworth',
#        'Los Angeles', 'Culver City', 'Studio City', 'West Hills',
#        'Encino', 'Panorama City', 'Woodland Hills', 'Eagle Rock',
#        'Canoga Park', 'Pacific Palisades', 'Santa Monica', 'Van Nuys',
#        'Northridge', 'Valley Glen', 'Valley Village', 'Venice',
#        'Lake Balboa', 'Sylmar', 'Playa Del Rey', 'Mission Hills',
#        'Gardena', 'North Hollywood', 'San Pedro', 'Sherman Oaks',
#        'Granada Hills', 'Porter Ranch', 'Beverly Hills', 'Marina Del Rey',
#        'Atwater Village', 'Pacoima', 'Tarzana', 'Tujunga', 'Calabasas',
#        'Sunland', 'Windsor Hills', 'Harbor City', 'Hollywood Hills',
#        'Glendale', 'North Hills', 'Sun Valley', 'Playa Vista',
#        'Monterey Hills', 'El Segundo', 'Echo Park', 'West Hollywood',
#        'Torrance', 'Winnetka', 'Brentwood', 'City Terrace', 'Toluca Lake',
#        'Shadow Hills', 'Arleta', 'Rancho Palos Verdes', 'Wilmington',
# ...

# %%
east_combined_csv.head(2)
# Out:
#    Unnamed: 0              property_type          address    city state  \
# 0           0  Single Family Residential     21 Grimes St  Boston    MA
# 1           1                Condo/Co-op  16 Mystic St #2  Boston    MA
#
#    zip_code   price  beds  baths  square_feet  lot_size year_built  \
# 0      2127  649999     2    2.0         1176       825       1890
# 1      2129  620000     2    1.0          758         0       1870
#
#    hoa_permonth                                                url   latitude  \
# 0             0  http://www.redfin.com/MA/Boston/21-Grimes-St-0...  42.333760
# 1           119  http://www.redfin.com/MA/Boston/16-Mystic-St-0...  42.379717
#
#    longitude
# 0 -71.051837
# 1 -71.062921

# %%
east_combined_csv.city.unique()
# Out:
# array(['Boston', 'Somerville', 'Brookline', 'Cambridge', 'Newton',
#        'Miami', 'Homestead', 'Nashville', 'Hermitage', 'Brentwood',
#        'Nolensville', 'Old Hickory', 'Antioch', 'Franklin', 'Madison',
#        'Goodlettsville', 'Joelton', 'Whites Creek', 'Mount Juliet',
#        'New York', 'Woodhaven', 'Richmond Hill', 'Jamaica', 'Brooklyn',
#        'Queens', 'Stuyvesant Hts', 'Flushing', 'Bensonhurst', 'Bronx',
#        'Staten Island', 'St. Albans', 'Bellerose', 'Howard Beach',
#        'Jackson Heights', 'Forest Hills', 'Glen Oaks', 'Kew Garden Hills',
#        'Corona', 'Valley Stream', 'Elmhurst', 'College Point',
#        'Floral Park', 'Bayside', 'Far Rockaway', 'S. Ozone Park',
#        'E. Elmhurst', 'Rego Park', 'Briarwood', 'Yonkers', 'Ozone Park',
#        'Ridgewood', 'Hollis', 'Kew Gardens', 'Whitestone',
#        'Middle Village', 'Little Neck', 'Malba', 'Flatlands',
#        'Fresh Meadows', 'Cornwall', 'Laurelton', 'Bushwick', 'Douglaston',
# ...

# %%
redfin_frames = [midwest_combined_csv, westcoast_combined_csv, east_combined_csv]

# %%
redfin_all = pd.concat(redfin_frames)

# %%
redfin_all.head(2)
# Out:
#    Unnamed: 0              property_type             address       city state  \
# 0         459                Vacant Land        000 Avilla E  Alexander    AR
# 1         493  Single Family Residential  9015 Springhill Rd  Alexander    AR
#
#   zip_code   price  beds  baths  square_feet  lot_size year_built  \
# 0    72002  600000     0    0.0            0   2613600    unknown
# 1    72002  175000     5    2.0         2556     69696       1974
#
#    hoa_permonth                                                url   latitude  \
# 0             0  http://www.redfin.com/AR/Beaver-Township/Avill...  34.683729
# 1             0  http://www.redfin.com/AR/Alexander/9015-Spring...  34.673700
#
#    longitude
# 0 -92.581063
# 1 -92.523410

# %%
redfin_drop = redfin_all.drop(columns=['Unnamed: 0'])

# %%
redfin_drop
# Out:
#                   property_type                        address        city  \
# 0                   Vacant Land                   000 Avilla E   Alexander
# 1     Single Family Residential             9015 Springhill Rd   Alexander
# 2     Single Family Residential              7105 Woodsgate Cv   Alexander
# 3     Single Family Residential                  5072 Peace Ln   Alexander
# 4      Mobile/Manufactured Home               15900 Shirley Dr   Alexander
# ...                         ...                            ...         ...
# 1723                Condo/Co-op         1441 Euclid St NW #104  Washington
# 1724                Condo/Co-op              18 9th St NE #408  Washington
# 1725                Condo/Co-op  1391 Pennsylvania Ave SE #439  Washington
# 1726                  Townhouse            1617 Potomac Ave SE  Washington
# 1727                Condo/Co-op         490 M St SW Unit W-608  Washington
#
# ...

# %%
redfin_all_data = redfin_drop.reset_index(drop=True)

# %%
redfin_all_data.to_csv('redfin_housing/redfin_resources/combined_regions/redfin_all_regions.csv')

# %%
population = pd.read_csv('population/population_categories.csv')

# %%
population.head(2)
# Out:
#      state        city  population pop_cat
# 0  Alabama     Thorsby        1980   small
# 1  Alabama  Deatsville        1154   small

# %%
temp_data = pd.read_csv('temperature/temp_min_and_max.csv')

# %%
temp_data.head(2)
# Out:
#   state_full  min_temp  max_temp state
# 0    Alabama      36.5      91.3    AL
# 1    Arizona      30.5      96.6    AZ

# %%
pop_temp_merge = population.merge(temp_data, left_on='state', right_on='state_full',
          suffixes=('_pop', '_temp'))

# %%
pop_temp_merge.head(2)
# Out:
#   state_pop        city  population pop_cat state_full  min_temp  max_temp  \
# 0   Alabama     Thorsby        1980   small    Alabama      36.5      91.3
# 1   Alabama  Deatsville        1154   small    Alabama      36.5      91.3
#
#   state_temp
# 0         AL
# 1         AL

# %%
pop_temp_drop_col = pop_temp_merge.drop(columns=['state_full'])

# %%
pop_temp_drop_col.head(2)
# Out:
#   state_pop        city  population pop_cat  min_temp  max_temp state_temp
# 0   Alabama     Thorsby        1980   small      36.5      91.3         AL
# 1   Alabama  Deatsville        1154   small      36.5      91.3         AL

# %%
pop_temp_rename = pop_temp_drop_col.rename(columns={"state_pop": "state", "state_temp": "state_abbr"})

# %%
pop_temp_rename.head(2)
# Out:
#      state        city  population pop_cat  min_temp  max_temp state_abbr
# 0  Alabama     Thorsby        1980   small      36.5      91.3         AL
# 1  Alabama  Deatsville        1154   small      36.5      91.3         AL

# %%
redfin_all_data.head(2)
# Out:
#                property_type             address       city state zip_code  \
# 0                Vacant Land        000 Avilla E  Alexander    AR    72002
# 1  Single Family Residential  9015 Springhill Rd  Alexander    AR    72002
#
#     price  beds  baths  square_feet  lot_size year_built  hoa_permonth  \
# 0  600000     0    0.0            0   2613600    unknown             0
# 1  175000     5    2.0         2556     69696       1974             0
#
#                                                  url   latitude  longitude
# 0  http://www.redfin.com/AR/Beaver-Township/Avill...  34.683729 -92.581063
# 1  http://www.redfin.com/AR/Alexander/9015-Spring...  34.673700 -92.523410

# %%
redfin_sort_state = redfin_all_data.sort_values(by=['state', 'city'])

# %%
redfin_sort_state
# Out:
#                   property_type                              address  \
# 0                   Vacant Land                         000 Avilla E
# 1     Single Family Residential                   9015 Springhill Rd
# 2     Single Family Residential                    7105 Woodsgate Cv
# 3     Single Family Residential                        5072 Peace Ln
# 4      Mobile/Manufactured Home                     15900 Shirley Dr
# ...                         ...                                  ...
# 1020                  Townhouse                     310 Amber Dr #31
# 1021  Single Family Residential                      531 Wilmette Rd
# 1022                Vacant Land                      Lt1 Congress St
# 1023  Single Family Residential  Lt188 Bailey Ests Unit ''Georgian''
# 1024  Single Family Residential    Lt187 Bailey Ests Unit ''Bailey''
#
#               city state zip_code   price  beds  baths  square_feet  lot_size  \
# ...

# %%
redfin_dropna = redfin_sort_state.dropna()

# %%
redfin_dropna
# Out:
#                   property_type                              address  \
# 0                   Vacant Land                         000 Avilla E
# 1     Single Family Residential                   9015 Springhill Rd
# 2     Single Family Residential                    7105 Woodsgate Cv
# 3     Single Family Residential                        5072 Peace Ln
# 4      Mobile/Manufactured Home                     15900 Shirley Dr
# ...                         ...                                  ...
# 1020                  Townhouse                     310 Amber Dr #31
# 1021  Single Family Residential                      531 Wilmette Rd
# 1022                Vacant Land                      Lt1 Congress St
# 1023  Single Family Residential  Lt188 Bailey Ests Unit ''Georgian''
# 1024  Single Family Residential    Lt187 Bailey Ests Unit ''Bailey''
#
#               city state zip_code   price  beds  baths  square_feet  lot_size  \
# ...

# %%
pop_temp_rename.sort_values(by=['state_abbr', 'city'])
# Out:
#          state        city  population pop_cat  min_temp  max_temp state_abbr
# 205    Alabama   Abbeville        2688  middle      36.5      91.3         AL
# 214    Alabama  Adamsville        4522  middle      36.5      91.3         AL
# 121    Alabama     Addison         758   small      36.5      91.3         AL
# 291    Alabama       Akron         356   small      36.5      91.3         AL
# 287    Alabama   Alabaster       30352  middle      36.5      91.3         AL
# ...        ...         ...         ...     ...       ...       ...        ...
# 19188  Wyoming   Wamsutter         451   small      11.5      80.7         WY
# 19235  Wyoming   Wheatland        3627  middle      11.5      80.7         WY
# 19267  Wyoming     Worland        5487  middle      11.5      80.7         WY
# 19184  Wyoming      Wright        1807   small      11.5      80.7         WY
# 19258  Wyoming       Yoder         151   small      11.5      80.7         WY
#
# [19276 rows x 7 columns]

# %%
housing_complete_merge = redfin_dropna.merge(pop_temp_rename, left_on=['state', 'city'], right_on=['state_abbr', 'city'])

# %%
housing_complete_merge
# Out:
#                   property_type                address        city state_x  \
# 0                   Vacant Land           000 Avilla E   Alexander      AR
# 1     Single Family Residential     9015 Springhill Rd   Alexander      AR
# 2     Single Family Residential      7105 Woodsgate Cv   Alexander      AR
# 3     Single Family Residential          5072 Peace Ln   Alexander      AR
# 4      Mobile/Manufactured Home       15900 Shirley Dr   Alexander      AR
# ...                         ...                    ...         ...     ...
# 4078                Vacant Land  Lt3 County Highway Nn   West Bend      WI
# 4079                Condo/Co-op    1415 Watercress Cir   West Bend      WI
# 4080  Single Family Residential      186 W Paradise Dr   West Bend      WI
# 4081    Multi-Family (2-4 Unit)    224 E Washington St   West Bend      WI
# 4082                  Townhouse       310 Amber Dr #31  Whitewater      WI
#
# ...

# %%
housing_complete_drop = housing_complete_merge.drop(columns=['state_y', 'state_x'])

# %%
housing_complete_drop
# Out:
#                   property_type                address        city zip_code  \
# 0                   Vacant Land           000 Avilla E   Alexander    72002
# 1     Single Family Residential     9015 Springhill Rd   Alexander    72002
# 2     Single Family Residential      7105 Woodsgate Cv   Alexander    72002
# 3     Single Family Residential          5072 Peace Ln   Alexander    72002
# 4      Mobile/Manufactured Home       15900 Shirley Dr   Alexander    72002
# ...                         ...                    ...         ...      ...
# 4078                Vacant Land  Lt3 County Highway Nn   West Bend    53095
# 4079                Condo/Co-op    1415 Watercress Cir   West Bend    53095
# 4080  Single Family Residential      186 W Paradise Dr   West Bend    53095
# 4081    Multi-Family (2-4 Unit)    224 E Washington St   West Bend    53095
# 4082                  Townhouse       310 Amber Dr #31  Whitewater    53190
#
# ...

# %%
housing_complete_drop['house_id'] = housing_complete_drop.index + 1

# %%
housing_complete_drop
# Out:
#                   property_type                address        city zip_code  \
# 0                   Vacant Land           000 Avilla E   Alexander    72002
# 1     Single Family Residential     9015 Springhill Rd   Alexander    72002
# 2     Single Family Residential      7105 Woodsgate Cv   Alexander    72002
# 3     Single Family Residential          5072 Peace Ln   Alexander    72002
# 4      Mobile/Manufactured Home       15900 Shirley Dr   Alexander    72002
# ...                         ...                    ...         ...      ...
# 4078                Vacant Land  Lt3 County Highway Nn   West Bend    53095
# 4079                Condo/Co-op    1415 Watercress Cir   West Bend    53095
# 4080  Single Family Residential      186 W Paradise Dr   West Bend    53095
# 4081    Multi-Family (2-4 Unit)    224 E Washington St   West Bend    53095
# 4082                  Townhouse       310 Amber Dr #31  Whitewater    53190
#
# ...

# %%
cols = list(housing_complete_drop.columns.values)
cols
# Out:
# ['property_type',
#  'address',
#  'city',
#  'zip_code',
#  'price',
#  'beds',
#  'baths',
#  'square_feet',
#  'lot_size',
#  'year_built',
#  'hoa_permonth',
#  'url',
#  'latitude',
#  'longitude',
#  'population',
#  'pop_cat',
#  'min_temp',
#  'max_temp',
#  'state_abbr',
#  'house_id']

# %%
complete_housing_data = housing_complete_drop[['house_id','property_type','address',
                                                'city','state_abbr','zip_code','price','beds','baths',
                                                'square_feet','lot_size','year_built','hoa_permonth',
                                                'population','pop_cat','min_temp','max_temp',
                                                'latitude','longitude','url']]

# %%
complete_housing_data
# Out:
#       house_id              property_type                address        city  \
# 0            1                Vacant Land           000 Avilla E   Alexander
# 1            2  Single Family Residential     9015 Springhill Rd   Alexander
# 2            3  Single Family Residential      7105 Woodsgate Cv   Alexander
# 3            4  Single Family Residential          5072 Peace Ln   Alexander
# 4            5   Mobile/Manufactured Home       15900 Shirley Dr   Alexander
# ...        ...                        ...                    ...         ...
# 4078      4079                Vacant Land  Lt3 County Highway Nn   West Bend
# 4079      4080                Condo/Co-op    1415 Watercress Cir   West Bend
# 4080      4081  Single Family Residential      186 W Paradise Dr   West Bend
# 4081      4082    Multi-Family (2-4 Unit)    224 E Washington St   West Bend
# 4082      4083                  Townhouse       310 Amber Dr #31  Whitewater
#
# ...

# %%
complete_housing_data.to_csv('housing_complete_data.csv')

# %%
housing_training_data = complete_housing_data[['house_id','price','beds','baths','square_feet','lot_size',
                                               'year_built','hoa_permonth','population','min_temp','max_temp' ]]

# %%
# housing_complete_drop.to_csv('housing_training_data.csv')
