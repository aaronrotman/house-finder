# %%
import pandas as pd

# %%
midwest_combined_csv = pd.read_csv("../redfin_housing/redfin_resources/combined_regions/redfin_midwest_combined.csv")
westcoast_combined_csv = pd.read_csv("../redfin_housing/redfin_resources/combined_regions/redfin_westcoast_combined.csv")
east_combined_csv = pd.read_csv("../redfin_housing/redfin_resources/combined_regions/redfin_eastcoast_combined.csv")
south_combined_csv = pd.read_csv("../redfin_housing/redfin_resources/combined_regions/redfin_south.csv")

# %%
midwest_combined_csv.head(2)
# Out:
#    Unnamed: 0              property_type                      address  \
# 0           0                Condo/Co-op  929 N Astor St Unit 2501-03
# 1           1  Single Family Residential           1075 Thornridge Ct
#
#          city state zip_code   price  beds  baths  square_feet  lot_size  \
# 0   Milwaukee    WI    53202  619900   2.0    2.0       1791.0       0.0
# 1  Brookfield    WI    53045  365000   4.0    2.5       2406.0   16988.0
#
#   year_built  hoa_permonth                                                url  \
# 0     1968.0        1246.0  http://www.redfin.com/WI/Milwaukee/929-N-Astor...
# 1     1978.0           0.0  http://www.redfin.com/WI/Brookfield/1075-Thorn...
#
#     latitude  longitude
# 0  43.043650 -87.899880
# 1  43.045303 -88.172795

# %%
# midwest_combined_csv.city.unique()

# %%
westcoast_combined_csv.head(2)
# Out:
#    Unnamed: 0              property_type             address   city state  \
# 0           0  Single Family Residential      2100 N 17th St  Boise    ID
# 1           1  Single Family Residential  4797 Arrowhead Way  Boise    ID
#
#   zip_code     price  beds  baths  square_feet  lot_size year_built  \
# 0    83702  899000.0   3.0    2.5       2500.0    6098.0       2020
# 1    83709  268900.0   3.0    1.0       1127.0    9583.0       1982
#
#    hoa_permonth                                                url   latitude  \
# 0           0.0  http://www.redfin.com/ID/Boise/2100-N-17th-St-...  43.639235
# 1           0.0  http://www.redfin.com/ID/Boise/4797-Arrowhead-...  43.559434
#
#     longitude
# 0 -116.209058
# 1 -116.276367

# %%
# westcoast_combined_csv.city.unique()

# %%
east_combined_csv.head(2)
# Out:
#    Unnamed: 0              property_type          address    city state  \
# 0           0  Single Family Residential     21 Grimes St  Boston    MA
# 1           1                Condo/Co-op  16 Mystic St #2  Boston    MA
#
#    zip_code     price  beds  baths  square_feet  lot_size year_built  \
# 0    2127.0  649999.0   2.0    2.0       1176.0     825.0       1890
# 1    2129.0  620000.0   2.0    1.0        758.0       0.0       1870
#
#    hoa_permonth                                                url   latitude  \
# 0           0.0  http://www.redfin.com/MA/Boston/21-Grimes-St-0...  42.333760
# 1         119.0  http://www.redfin.com/MA/Boston/16-Mystic-St-0...  42.379717
#
#    longitude
# 0 -71.051837
# 1 -71.062921

# %%
# east_combined_csv.city.unique()

# %%
south_combined_csv.head(2)
# Out:
#    Unnamed: 0              property_type           address            city  \
# 0           0  Single Family Residential  832 Southbend Ln  Vestavia Hills
# 1           1  Single Family Residential  833 Southbend Ln  Vestavia Hills
#
#   state  zip_code   price  beds  baths  square_feet  lot_size  year_built  \
# 0    AL     35243  650000     3    2.5          NaN    9147.0      2020.0
# 1    AL     35243  650000     3    2.5          NaN   15681.0      2020.0
#
#    hoa_permonth                                                url  latitude  \
# 0            67  http://www.redfin.com/AL/Vestavia-Hills/Unknow...   33.4399
# 1            67  http://www.redfin.com/AL/Vestavia-Hills/Unknow...   33.4399
#
#    longitude
# 0   -86.7936
# 1   -86.7936

# %%
# south_combined_csv.city.unique()

# %%
redfin_frames = [midwest_combined_csv, westcoast_combined_csv, east_combined_csv, south_combined_csv]

# %%
redfin_all = pd.concat(redfin_frames)

# %%
redfin_all.head(2)
# Out:
#    Unnamed: 0              property_type                      address  \
# 0           0                Condo/Co-op  929 N Astor St Unit 2501-03
# 1           1  Single Family Residential           1075 Thornridge Ct
#
#          city state zip_code     price  beds  baths  square_feet  lot_size  \
# 0   Milwaukee    WI    53202  619900.0   2.0    2.0       1791.0       0.0
# 1  Brookfield    WI    53045  365000.0   4.0    2.5       2406.0   16988.0
#
#   year_built  hoa_permonth                                                url  \
# 0     1968.0        1246.0  http://www.redfin.com/WI/Milwaukee/929-N-Astor...
# 1     1978.0           0.0  http://www.redfin.com/WI/Brookfield/1075-Thorn...
#
#     latitude  longitude
# 0  43.043650 -87.899880
# 1  43.045303 -88.172795

# %%
redfin_drop = redfin_all.drop(columns=['Unnamed: 0'])

# %%
redfin_drop
# Out:
#                   property_type                      address          city  \
# 0                   Condo/Co-op  929 N Astor St Unit 2501-03     Milwaukee
# 1     Single Family Residential           1075 Thornridge Ct    Brookfield
# 2     Single Family Residential              531 Wilmette Rd  Williams Bay
# 3     Single Family Residential          5825 Cedar Creek Rd       Grafton
# 4     Single Family Residential                1301 53rd Ave       Kenosha
# ...                         ...                          ...           ...
# 2422  Single Family Residential               Stonehaven A_1        Athens
# 2423  Single Family Residential                 Sunbeam IV A        Athens
# 2424  Single Family Residential                Branford II B        Athens
# 2425  Single Family Residential                Branford II A        Athens
# 2426  Single Family Residential               Timberland A-1        Athens
#
# ...

# %%
redfin_all_data = redfin_drop.reset_index(drop=True)

# %%
redfin_all_data.dtypes
# Out:
# property_type     object
# address           object
# city              object
# state             object
# zip_code          object
# price            float64
# beds             float64
# baths            float64
# square_feet      float64
# lot_size         float64
# year_built        object
# hoa_permonth     float64
# url               object
# latitude         float64
# longitude        float64
# dtype: object

# %%
redfin_all_data.loc[:,'city'] = redfin_all_data.loc[:, 'city'].astype("string")
redfin_all_data.loc[:,'state'] = redfin_all_data.loc[:, 'state'].astype("string")

# %%
redfin_all_data.dtypes
# Out:
# property_type     object
# address           object
# city              string
# state             string
# zip_code          object
# price            float64
# beds             float64
# baths            float64
# square_feet      float64
# lot_size         float64
# year_built        object
# hoa_permonth     float64
# url               object
# latitude         float64
# longitude        float64
# dtype: object

# %%
redfin_all_data_sorted = redfin_all_data.sort_values(by=['state', 'city'])
redfin_all_data_sorted
# Out:
#                   property_type                              address  \
# 3191  Single Family Residential                32996 Heather Glen Ct
# 3192  Single Family Residential                    70875 Lee Roy Ave
# 3193  Single Family Residential                   26890 Sterling Hwy
# 3194  Single Family Residential                   31513 Sterling Hwy
# 3195  Single Family Residential                      72960 Laida Ave
# ...                         ...                                  ...
# 97    Single Family Residential                 6259 N Berkeley Blvd
# 69                    Townhouse                     310 Amber Dr #31
# 2     Single Family Residential                      531 Wilmette Rd
# 261   Single Family Residential  Lt188 Bailey Ests Unit ''Georgian''
# 265   Single Family Residential    Lt187 Bailey Ests Unit ''Bailey''
#
#                city state zip_code     price  beds  baths  square_feet  \
# ...

# %%
redfin_all_data_sorted.to_csv('../redfin_housing/redfin_resources/combined_regions/redfin_all_regions.csv')
