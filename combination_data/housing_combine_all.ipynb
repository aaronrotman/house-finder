# %%
import pandas as pd

# %%
midwest_combined_csv = pd.read_csv("../redfin_housing/redfin_resources/combined_regions/redfin_midwest_combined.csv")
westcoast_combined_csv = pd.read_csv("../redfin_housing/redfin_resources/combined_regions/redfin_westcoast_combined.csv")
east_combined_csv = pd.read_csv("../redfin_housing/redfin_resources/combined_regions/redfin_eastcoast_combined.csv")
south_combined_csv = pd.read_csv("../redfin_housing/redfin_resources/combined_regions/redfin_south.csv")

# %%
midwest_combined_csv.head(2)
# Out:
#    Unnamed: 0              property_type             address   city state  \
# 0           0  Single Family Residential      2100 N 17th St  Boise    ID
# 1           1  Single Family Residential  4797 Arrowhead Way  Boise    ID
#
#   zip_code     price  beds  baths  square_feet  lot_size year_built  \
# 0    83702  899000.0   3.0    2.5       2500.0    6098.0     2020.0
# 1    83709  268900.0   3.0    1.0       1127.0    9583.0     1982.0
#
#    hoa_permonth                                                url   latitude  \
# 0           0.0  http://www.redfin.com/ID/Boise/2100-N-17th-St-...  43.639235
# 1           0.0  http://www.redfin.com/ID/Boise/4797-Arrowhead-...  43.559434
#
#     longitude
# 0 -116.209058
# 1 -116.276367

# %%
# midwest_combined_csv.city.unique()

# %%
westcoast_combined_csv.head(2)
# Out:
#    Unnamed: 0              property_type             address   city state  \
# 0           0  Single Family Residential      2100 N 17th St  Boise    ID
# 1           1  Single Family Residential  4797 Arrowhead Way  Boise    ID
#
#   zip_code     price  beds  baths  square_feet  lot_size year_built  \
# 0    83702  899000.0   3.0    2.5       2500.0    6098.0     2020.0
# 1    83709  268900.0   3.0    1.0       1127.0    9583.0     1982.0
#
#    hoa_permonth                                                url   latitude  \
# 0           0.0  http://www.redfin.com/ID/Boise/2100-N-17th-St-...  43.639235
# 1           0.0  http://www.redfin.com/ID/Boise/4797-Arrowhead-...  43.559434
#
#     longitude
# 0 -116.209058
# 1 -116.276367

# %%
# westcoast_combined_csv.city.unique()

# %%
east_combined_csv.head(2)
# Out:
#    Unnamed: 0              property_type          address    city state  \
# 0           0  Single Family Residential     21 Grimes St  Boston    MA
# 1           1                Condo/Co-op  16 Mystic St #2  Boston    MA
#
#    zip_code     price  beds  baths  square_feet  lot_size year_built  \
# 0    2127.0  649999.0   2.0    2.0       1176.0     825.0     1890.0
# 1    2129.0  620000.0   2.0    1.0        758.0       0.0     1870.0
#
#    hoa_permonth                                                url   latitude  \
# 0           0.0  http://www.redfin.com/MA/Boston/21-Grimes-St-0...  42.333760
# 1         119.0  http://www.redfin.com/MA/Boston/16-Mystic-St-0...  42.379717
#
#    longitude
# 0 -71.051837
# 1 -71.062921

# %%
# east_combined_csv.city.unique()

# %%
south_combined_csv.head(2)
# Out:
#    Unnamed: 0              property_type           address            city  \
# 0           0  Single Family Residential  832 Southbend Ln  Vestavia Hills
# 1           1  Single Family Residential  833 Southbend Ln  Vestavia Hills
#
#   state  zip_code     price  beds  baths  square_feet  lot_size  year_built  \
# 0    AL     35243  650000.0   3.0    2.5          NaN    9147.0      2020.0
# 1    AL     35243  650000.0   3.0    2.5          NaN   15681.0      2020.0
#
#    hoa_permonth                                                url  latitude  \
# 0            67  http://www.redfin.com/AL/Vestavia-Hills/Unknow...   33.4399
# 1            67  http://www.redfin.com/AL/Vestavia-Hills/Unknow...   33.4399
#
#    longitude
# 0   -86.7936
# 1   -86.7936

# %%
# south_combined_csv.city.unique()

# %%
redfin_frames = [midwest_combined_csv, westcoast_combined_csv, east_combined_csv, south_combined_csv]

# %%
redfin_all = pd.concat(redfin_frames)

# %%
redfin_all.head(2)
# Out:
#    Unnamed: 0              property_type             address   city state  \
# 0           0  Single Family Residential      2100 N 17th St  Boise    ID
# 1           1  Single Family Residential  4797 Arrowhead Way  Boise    ID
#
#   zip_code     price  beds  baths  square_feet  lot_size year_built  \
# 0    83702  899000.0   3.0    2.5       2500.0    6098.0     2020.0
# 1    83709  268900.0   3.0    1.0       1127.0    9583.0     1982.0
#
#    hoa_permonth                                                url   latitude  \
# 0           0.0  http://www.redfin.com/ID/Boise/2100-N-17th-St-...  43.639235
# 1           0.0  http://www.redfin.com/ID/Boise/4797-Arrowhead-...  43.559434
#
#     longitude
# 0 -116.209058
# 1 -116.276367

# %%
redfin_drop = redfin_all.drop(columns=['Unnamed: 0'])

# %%
redfin_drop
# Out:
#                   property_type                   address    city state  \
# 0     Single Family Residential            2100 N 17th St   Boise    ID
# 1     Single Family Residential        4797 Arrowhead Way   Boise    ID
# 2                   Vacant Land            747 E Orion Dr   Boise    ID
# 3     Single Family Residential  12572 W Hidden Valley Dr   Boise    ID
# 4     Single Family Residential            547 E Orion Ct   Boise    ID
# ...                         ...                       ...     ...   ...
# 3549  Single Family Residential            Stonehaven A_1  Athens    AL
# 3550  Single Family Residential              Sunbeam IV A  Athens    AL
# 3551  Single Family Residential             Branford II B  Athens    AL
# 3552  Single Family Residential             Branford II A  Athens    AL
# 3553  Single Family Residential            Timberland A-1  Athens    AL
#
#      zip_code      price  beds  baths  square_feet  lot_size year_built  \
# 0       83702   899000.0   3.0    2.5       2500.0    6098.0     2020.0
# 1       83709   268900.0   3.0    1.0       1127.0    9583.0     1982.0
# 2       83702   400000.0   0.0    0.0          0.0   15681.0    unknown
# 3       83709   359000.0   3.0    2.0       2008.0    8712.0     2006.0
# 4       83702  2490000.0   5.0    4.5       4695.0   25351.0     2007.0
# ...       ...        ...   ...    ...          ...       ...        ...
# 3549    35613   362900.0   4.0    3.0       3380.0       NaN        NaN
# 3550    35611   225990.0   3.0    2.0       1685.0       NaN        NaN
# 3551    35611   248990.0   3.0    2.0       2058.0       NaN        NaN
# 3552    35611   248990.0   3.0    2.0       2058.0       NaN        NaN
# 3553    35613   353900.0   4.0    2.5       3325.0       NaN        NaN
#
#       hoa_permonth                                                url  \
# 0              0.0  http://www.redfin.com/ID/Boise/2100-N-17th-St-...
# 1              0.0  http://www.redfin.com/ID/Boise/4797-Arrowhead-...
# 2            103.0  http://www.redfin.com/ID/Boise/747-E-Orion-Dr-...
# 3             28.0  http://www.redfin.com/ID/Boise/12572-W-Hidden-...
# 4            117.0  http://www.redfin.com/ID/Boise/547-E-Orion-Ct-...
# ...            ...                                                ...
# 3549           0.0  http://www.redfin.com/AL/Athens/Legacy-Grove/S...
# 3550           0.0  http://www.redfin.com/AL/Athens/Park-Place/Sun...
# 3551           0.0  http://www.redfin.com/AL/Athens/Park-Place/Bra...
# 3552           0.0  http://www.redfin.com/AL/Athens/Park-Place/Bra...
# 3553           0.0  http://www.redfin.com/AL/Athens/Legacy-Grove/T...
#
#        latitude   longitude
# 0     43.639235 -116.209058
# 1     43.559434 -116.276367
# 2     43.637653 -116.180297
# 3     43.537023 -116.338323
# 4     43.636705 -116.183007
# ...         ...         ...
# 3549  34.748178  -86.868634
# 3550  34.791124  -86.966922
# 3551  34.791124  -86.966922
# 3552  34.791124  -86.966922
# 3553  34.748178  -86.868634
#
# [11184 rows x 15 columns]

# %%
redfin_all_data = redfin_drop.reset_index(drop=True)

# %%
redfin_all_data.dtypes
# Out:
# property_type     object
# address           object
# city              object
# state             object
# zip_code          object
# price            float64
# beds             float64
# baths            float64
# square_feet      float64
# lot_size         float64
# year_built        object
# hoa_permonth     float64
# url               object
# latitude         float64
# longitude        float64
# dtype: object

# %%
redfin_all_data.loc[:,'city'] = redfin_all_data.loc[:, 'city'].astype("string")
redfin_all_data.loc[:,'state'] = redfin_all_data.loc[:, 'state'].astype("string")

# %%
redfin_all_data.dtypes
# Out:
# property_type     object
# address           object
# city              string
# state             string
# zip_code          object
# price            float64
# beds             float64
# baths            float64
# square_feet      float64
# lot_size         float64
# year_built        object
# hoa_permonth     float64
# url               object
# latitude         float64
# longitude        float64
# dtype: object

# %%
redfin_all_data_sorted = redfin_all_data.sort_values(by=['state', 'city'])
redfin_all_data_sorted
# Out:
#                   property_type                    address          city  \
# 4870  Single Family Residential      32996 Heather Glen Ct  Anchor Point
# 4871  Single Family Residential          70875 Lee Roy Ave  Anchor Point
# 4872  Single Family Residential         26890 Sterling Hwy  Anchor Point
# 4873  Single Family Residential         31513 Sterling Hwy  Anchor Point
# 4874  Single Family Residential            72960 Laida Ave  Anchor Point
# ...                         ...                        ...           ...
# 4868                  Townhouse  2705 SW Sylvan Heights Dr       Seattle
# 2434  Single Family Residential           3020 NE 145th St     Shoreline
# 4869  Single Family Residential           3020 NE 145th St     Shoreline
# 2085                Condo/Co-op      730 SE Fairwinds Loop     Vancouver
# 4520                Condo/Co-op      730 SE Fairwinds Loop     Vancouver
#
#      state zip_code     price  beds  baths  square_feet  lot_size year_built  \
# 4870    AK  99556.0  369900.0   5.0   3.00       2500.0  404672.0     2016.0
# 4871    AK  99556.0  319000.0   2.0   2.00       1456.0  125452.0     2002.0
# 4872    AK  99556.0  115000.0   2.0   1.00        896.0   86248.0     2009.0
# 4873    AK  99556.0  205000.0   3.0   1.00       1423.0   78408.0     1962.0
# 4874    AK  99556.0  299000.0   2.0   2.00       2185.0   78843.0     1998.0
# ...    ...      ...       ...   ...    ...          ...       ...        ...
# 4868    WA    98106  515000.0   2.0   2.25       1420.0    1245.0     2007.0
# 2434    WA    98155  599000.0   3.0   1.00       1020.0    6135.0     1947.0
# 4869    WA    98155  599000.0   3.0   1.00       1020.0    6135.0     1947.0
# 2085    WA    98661  365000.0   3.0   2.00       1324.0       0.0     2001.0
# 4520    WA    98661  365000.0   3.0   2.00       1324.0       0.0     2001.0
#
#       hoa_permonth                                                url  \
# 4870           0.0  http://www.redfin.com/AK/Unknown/32996-HEATHER...
# 4871           0.0  http://www.redfin.com/AK/Anchor-Point/70875-Le...
# 4872           0.0  http://www.redfin.com/AK/Anchor-Point/26890-St...
# 4873           0.0  http://www.redfin.com/AK/Anchor-Point/31513-St...
# 4874           0.0  http://www.redfin.com/AK/Anchor-Point/72960-La...
# ...            ...                                                ...
# 4868         190.0  http://www.redfin.com/WA/Seattle/2705-SW-Sylva...
# 2434           0.0  http://www.redfin.com/WA/Shoreline/3020-NE-145...
# 4869           0.0  http://www.redfin.com/WA/Shoreline/3020-NE-145...
# 2085         237.0  http://www.redfin.com/WA/Vancouver/730-SE-Fair...
# 4520         237.0  http://www.redfin.com/WA/Vancouver/730-SE-Fair...
#
#        latitude   longitude
# 4870  59.794550 -151.827787
# 4871  59.845004 -151.787534
# 4872  59.882706 -151.782732
# 4873  59.816224 -151.827229
# 4874  59.781840 -151.851596
# ...         ...         ...
# 4868  47.539596 -122.368164
# 2434  47.734004 -122.295562
# 4869  47.734004 -122.295562
# 2085  45.615925 -122.652918
# 4520  45.615925 -122.652918
#
# [11184 rows x 15 columns]

# %%
redfin_all_data_sorted.to_csv('../redfin_housing/redfin_resources/combined_regions/redfin_all_regions.csv')
