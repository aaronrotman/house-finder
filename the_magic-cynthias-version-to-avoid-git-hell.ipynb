# %%
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neighbors import NearestNeighbors
import pandas as pd
import os
from sklearn import tree
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
import numpy as np
from sklearn.cluster import KMeans
# %matplotlib inline
from sklearn.preprocessing import StandardScaler
import warnings
warnings.simplefilter('ignore')
import numpy as np

# %%
housing_training_data = pd.read_csv("housing_training_data.csv")
housing_training_data.head()
# Out:
#    house_id      price  beds  baths  square_feet  lot_size  hoa_permonth  \
# 0         1   795000.0   5.0    3.0       2080.0    7250.0           0.0
# 1         2   795000.0   5.0    3.0       2080.0    7250.0           0.0
# 2         3  1189000.0   4.0    3.5       1482.0    5398.0           0.0
# 3         4  1189000.0   4.0    3.5       1482.0    5398.0           0.0
# 4         5  4295000.0   4.0    5.5       4081.0    6499.0           0.0
#
#    Summer Temp  Winter Temp  population
# 0         79.0         51.0     31068.0
# 1         79.0         51.0     31068.0
# 2         79.0         51.0     28168.0
# 3         79.0         51.0     28168.0
# 4         79.0         51.0     34109.0

# %%
house_data_for_results = pd.read_csv("combination_data/housing_complete_data.csv")
house_data_for_results.head()
# Out:
#    Unnamed: 0  house_id              property_type            address  \
# 0           0         1  Single Family Residential      9765 Vena Ave
# 1           1         2  Single Family Residential      9765 Vena Ave
# 2           2         3                  Townhouse   3152 Casitas Ave
# 3           3         4                  Townhouse   3152 Casitas Ave
# 4           4         5  Single Family Residential  221 S Willaman Dr
#
#               city state zip_code      price  beds  baths  ...  lot_size  \
# 0           Arleta    CA  91331.0   795000.0   5.0    3.0  ...    7250.0
# 1           Arleta    CA  91331.0   795000.0   5.0    3.0  ...    7250.0
# 2  Atwater Village    CA  90039.0  1189000.0   4.0    3.5  ...    5398.0
# 3  Atwater Village    CA  90039.0  1189000.0   4.0    3.5  ...    5398.0
# 4    Beverly Hills    CA  90211.0  4295000.0   4.0    5.5  ...    6499.0
#
#    year_built hoa_permonth                                                url  \
# 0      1948.0          0.0  http://www.redfin.com/CA/Arleta/9765-Vena-Ave-...
# 1      1948.0          0.0  http://www.redfin.com/CA/Arleta/9765-Vena-Ave-...
# 2      1938.0          0.0  http://www.redfin.com/CA/Los-Angeles/3152-Casi...
# 3      1938.0          0.0  http://www.redfin.com/CA/Los-Angeles/3152-Casi...
# 4      2018.0          0.0  http://www.redfin.com/CA/Beverly-Hills/221-S-W...
#
#     latitude   longitude  Summer Temp  Winter Temp  population  pop_cat
# 0  34.247852 -118.428107         79.0         51.0     31068.0   middle
# 1  34.247852 -118.428107         79.0         51.0     31068.0   middle
# 2  34.113874 -118.249714         79.0         51.0     28168.0   middle
# 3  34.113874 -118.249714         79.0         51.0     28168.0   middle
# 4  34.063496 -118.380685         79.0         51.0     34109.0   middle
#
# [5 rows x 21 columns]

# %%
X = housing_training_data[["Summer Temp", "Winter Temp", "population", "square_feet", 'price', "beds", 'baths', "lot_size", 'hoa_permonth', 
                          ]]
print(X.shape)
# Out:
# (7604, 9)

# %%
X.head(100)
# Out:
#     Summer Temp  Winter Temp  population  square_feet      price  beds  baths  \
# 0          79.0         51.0     31068.0       2080.0   795000.0   5.0    3.0
# 1          79.0         51.0     31068.0       2080.0   795000.0   5.0    3.0
# 2          79.0         51.0     28168.0       1482.0  1189000.0   4.0    3.5
# 3          79.0         51.0     28168.0       1482.0  1189000.0   4.0    3.5
# 4          79.0         51.0     34109.0       4081.0  4295000.0   4.0    5.5
# ..          ...          ...         ...          ...        ...   ...    ...
# 95         76.0         49.0     46781.0       1714.0   899000.0   2.0    2.5
# 96         76.0         49.0     46781.0       1656.0   899000.0   3.0    2.5
# 97         76.0         49.0     46781.0       1646.0  1150000.0   2.0    2.0
# 98         76.0         49.0     46781.0        506.0   365000.0   1.0    1.0
# 99         76.0         49.0     46781.0       2458.0  1595000.0   4.0    3.0
#
#     lot_size  hoa_permonth
# 0     7250.0           0.0
# 1     7250.0           0.0
# 2     5398.0           0.0
# 3     5398.0           0.0
# 4     6499.0           0.0
# ..       ...           ...
# 95       0.0         390.0
# 96       0.0         500.0
# 97   21004.0         605.0
# 98  292032.0         220.0
# 99    8500.0           0.0
#
# [100 rows x 9 columns]

# %%
data = X.copy()

# %%
# from sklearn.model_selection import train_test_split

# X_train, X_test= train_test_split(X, random_state=42)

# X_train.head()

# %%
from sklearn.preprocessing import StandardScaler
X_scaler = StandardScaler().fit(X)
X_scaler
# Out:
# StandardScaler()

# %%
X_scaled = X_scaler.transform(X)
X_scaled
# Out:
# array([[-0.12019135,  0.71909948, -0.68110291, ...,  0.41060305,
#         -0.03836231, -0.20217592],
#        [-0.12019135,  0.71909948, -0.68110291, ...,  0.41060305,
#         -0.03836231, -0.20217592],
#        [-0.12019135,  0.71909948, -0.68372149, ...,  0.67234809,
#         -0.0405828 , -0.20217592],
#        ...,
#        [-1.30942855,  0.19509817, -0.66129286, ..., -0.63637708,
#         -0.03969916, -0.20217592],
#        [-0.12019135, -0.85290445, -0.56306522, ..., -0.11288701,
#         -0.04705484, -0.00715146],
#        [-0.12019135, -0.85290445, -0.56306522, ..., -0.11288701,
#         -0.04705484, -0.00715146]])

# %%
kmeans = KMeans(n_clusters=16)

# %%
kmeans.fit(X_scaled)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-8a1f7c7d593a> in <module>
# ----> 1 kmeans.fit(X_scaled)
#
# ~/opt/anaconda3/envs/PythonAdv/lib/python3.6/site-packages/sklearn/cluster/_kmeans.py in fit(self, X, y, sample_weight)
#     992                                 dtype=[np.float64, np.float32],
#     993                                 order='C', copy=self.copy_x,
# --> 994                                 accept_large_sparse=False)
#     995         # verify that the number of samples given is larger than k
#     996         if _num_samples(X) < self.n_clusters:
#
# ~/opt/anaconda3/envs/PythonAdv/lib/python3.6/site-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     418                     f"requires y to be passed, but the target y is None."
#     419                 )
# --> 420             X = check_array(X, **check_params)
#     421             out = X
#     422         else:
#
# ~/opt/anaconda3/envs/PythonAdv/lib/python3.6/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      71                           FutureWarning)
#      72         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 73         return f(**kwargs)
#      74     return inner_f
#      75
#
# ~/opt/anaconda3/envs/PythonAdv/lib/python3.6/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     644         if force_all_finite:
#     645             _assert_all_finite(array,
# --> 646                                allow_nan=force_all_finite == 'allow-nan')
#     647
#     648     if ensure_min_samples > 0:
#
# ~/opt/anaconda3/envs/PythonAdv/lib/python3.6/site-packages/sklearn/utils/validation.py in _assert_all_finite(X, allow_nan, msg_dtype)
#      98                     msg_err.format
#      99                     (type_err,
# --> 100                      msg_dtype if msg_dtype is not None else X.dtype)
#     101             )
#     102     # for object dtype data, we only check for NaNs (GH-13254)
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').

# %%
predicted_clusters = kmeans.predict(X)

# %%
X_scaled

# %%
Xlist = X_scaled.to_numpy()

# %%
Xlist

# %% [markdown]
# ### HERE BEGINS THE MAGIC

# %%
kmeans.fit(Xlist)

predicted_clusters = kmeans.predict(Xlist)
#TESTING INFO INPUT BLAH BLAH
# predicted_clusters = [this is where we put the array of inputed data]

# %%
predicted_clusters

# %%
# Plot the clusters
plt.scatter(Xlist[:, 0], Xlist[:, 1], c=predicted_clusters, s=50, cmap='viridis')
plt.show()

# %%
# Print the cluster centers and cluster labels
centers = kmeans.cluster_centers_
labels = kmeans.labels_

# %%
centers

# %%
plt.scatter(Xlist[:, 0], Xlist[:, 1], c=labels, s=50, cmap='viridis')
plt.scatter(centers[:, 0], centers[:, 1], c='black', s=200, alpha=0.5)

plt.show()

# %%
cat = kmeans.predict(Xlist[0].reshape(1, -1))

# %%
Xlist[0]

# %%
Xlist[1]

# %%
X

# %%
house_list = []

for i in range(4000):
    if kmeans.predict(Xlist[i].reshape(1, -1)) == cat:
        print (housing_training_data.iloc[i])
        print (housing_training_data.house_id[i])
        house_list.append(housing_training_data.house_id[i])
        print (Xlist[i])
        print (kmeans.predict(Xlist[i].reshape(1, -1)))

# %%
house_list
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-9f256fed078e> in <module>
# ----> 1 house_list
#
# NameError: name 'house_list' is not defined

# %%
# now we go back to the orginal dataframe and find these house_ids
# df.loc[df['column_name'] == some_value]
find_it = house_data_for_results.loc[housing_training_data['house_id'] == 1]

# %%
find_it
# Out:
#    Unnamed: 0  house_id              property_type        address    city  \
# 0           0         1  Single Family Residential  9765 Vena Ave  Arleta
#
#   state zip_code     price  beds  baths  ...  lot_size  year_built  \
# 0    CA  91331.0  795000.0   5.0    3.0  ...    7250.0      1948.0
#
#   hoa_permonth                                                url   latitude  \
# 0          0.0  http://www.redfin.com/CA/Arleta/9765-Vena-Ave-...  34.247852
#
#     longitude  Summer Temp  Winter Temp  population  pop_cat
# 0 -118.428107         79.0         51.0     31068.0   middle
#
# [1 rows x 21 columns]

# %%
print(f'{find_it.house_id} and {find_it.price}'" in the US.")
# Out:
# 0    1
# Name: house_id, dtype: int64 and 0    795000.0
# Name: price, dtype: float64 in the US.

# %%
# for row in housing_training_data.itertuples():
# #     if (housing_training_data.house_id == "1"):
#     print(row)

# %%
house_data_for_results.head()
# Out:
#    Unnamed: 0  house_id              property_type            address  \
# 0           0         1  Single Family Residential      9765 Vena Ave
# 1           1         2  Single Family Residential      9765 Vena Ave
# 2           2         3                  Townhouse   3152 Casitas Ave
# 3           3         4                  Townhouse   3152 Casitas Ave
# 4           4         5  Single Family Residential  221 S Willaman Dr
#
#               city state zip_code      price  beds  baths  ...  lot_size  \
# 0           Arleta    CA  91331.0   795000.0   5.0    3.0  ...    7250.0
# 1           Arleta    CA  91331.0   795000.0   5.0    3.0  ...    7250.0
# 2  Atwater Village    CA  90039.0  1189000.0   4.0    3.5  ...    5398.0
# 3  Atwater Village    CA  90039.0  1189000.0   4.0    3.5  ...    5398.0
# 4    Beverly Hills    CA  90211.0  4295000.0   4.0    5.5  ...    6499.0
#
#    year_built hoa_permonth                                                url  \
# 0      1948.0          0.0  http://www.redfin.com/CA/Arleta/9765-Vena-Ave-...
# 1      1948.0          0.0  http://www.redfin.com/CA/Arleta/9765-Vena-Ave-...
# 2      1938.0          0.0  http://www.redfin.com/CA/Los-Angeles/3152-Casi...
# 3      1938.0          0.0  http://www.redfin.com/CA/Los-Angeles/3152-Casi...
# 4      2018.0          0.0  http://www.redfin.com/CA/Beverly-Hills/221-S-W...
#
#     latitude   longitude  Summer Temp  Winter Temp  population  pop_cat
# 0  34.247852 -118.428107         79.0         51.0     31068.0   middle
# 1  34.247852 -118.428107         79.0         51.0     31068.0   middle
# 2  34.113874 -118.249714         79.0         51.0     28168.0   middle
# 3  34.113874 -118.249714         79.0         51.0     28168.0   middle
# 4  34.063496 -118.380685         79.0         51.0     34109.0   middle
#
# [5 rows x 21 columns]
